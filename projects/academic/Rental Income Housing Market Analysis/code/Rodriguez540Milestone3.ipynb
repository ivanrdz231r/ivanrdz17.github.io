# %% [markdown]
# # Project: Milestone 3

# %% [markdown]
# ## Cleaning/Formatting Website Data Source

# %% [markdown]
# ***Instructions)***
#
# Perform at least 5 data transformation and/or cleansing steps to your flat file data. The below examples are not required - they are just potential transformations you could do. If your data doesn't work for these scenarios, complete different transformations. You can do the same transformation multiple times if needed to clean your data. The goal is a clean dataset at the end of the milestone.
#
# - Replace Headers
# - Format data into a more readable format
# - Identify outliers and bad data
# - Find duplicates
# - Fix casing or inconsistent values
# - Conduct Fuzzy Matching
#
# Make sure you clearly label each transformation (Step #1, Step #2, etc.) in your code and describe what it is doing in 1-2 sentences. You can submit a Jupyter Notebook or a PDF of your code. If you submit a .py file you need to also include a PDF or attachment of your results.

# %% [markdown]
# ***Answer)***

# %% [markdown]
# **#0. Intro Work**

# %% [markdown]
# When inspecting the source HTML Elements to locate the table I found following class identifier:
#
# - class = "wikitable sortable jquery-tablesorter"
#
# There are three tables in a list in this class value

# %%
# Read the page using bs4
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Open and read the html file with BeautifulSoup
with open("List of U.S. cities by adjusted per capita personal income - Wikipedia.html", "r", encoding="utf-8") as htmlFile:
    soup = BeautifulSoup(htmlFile, "html.parser")
    
tables = soup.find_all('table')

# This code reads the table into a pandas df, and sets which tables[] to select when reading. 
df = pd.read_html(str(tables[0]))[0] # Selecting the first table

df.head(50)
# Out:
#                         50 largest metropolitan areas  \
# 0   1. New York City-Newark-Jersey City, NY-NJ-PA MSA
# 1           2. Los Angeles-Long Beach-Anaheim, CA MSA
# 2           3. Chicago-Naperville-Elgin, IL-IN-WI MSA
# 3              4. Dallas-Fort Worth-Arlington, TX MSA
# 4         5. Houston-The Woodlands-Sugar Land, TX MSA
# 5   6. Washington-Arlington-Alexandria, DC-VA-MD-W...
# 6    7. Miami-Fort Lauderdale-West Palm Beach, FL MSA
# 7   8. Philadelphia-Camden-Wilmington, PA-NJ-DE-MD...
# 8         9. Atlanta-Sandy Springs-Alpharetta, GA MSA
# 9                   10. Phoenix-Mesa-Chandler, AZ MSA
# 10   11. Boston-Worcester-Providence, MA-RI-NH-CT CSA
# 11         12. San Francisco-Oakland-Berkeley, CA MSA
# 12       13. Riverside-San Bernardino-Ontario, CA MSA
# 13                14. Detroit–Warren–Dearborn, MI MSA
# 14                15. Seattle-Tacoma-Bellevue, WA MSA
# 15    16. Minneapolis-St. Paul-Bloomington, MN-WI MSA
# 16         17. San Diego-Chula Vista-Carlsbad, CA MSA
# 17        18. Tampa-St. Petersburg-Clearwater, FL MSA
# 18                  19 Denver-Aurora-Lakewood, CO MSA
# 19                           20. St. Louis, MO-IL MSA
# 20              21. Baltimore-Columbia-Towson, MD MSA
# 21          22. Charlotte-Concord-Gastonia, NC-SC MSA
# 22              23. Orlando-Kissimmee-Sanford, FL MSA
# 23              24. San Antonio-New Braunfels, TX MSA
# 24        25. Portland-Vancouver-Hillsboro, OR-WA MSA
# 25            26. Sacramento-Roseville-Folsom, CA MSA
# 26    27. Pittsburgh-New Castle-Weirton, PA-OH-WV CSA
# 27           28. Las Vegas-Henderson-Paradise, NV MSA
# 28           29. Austin-Round Rock-Georgetown, TX MSA
# 29                       30. Cincinnati, OH-KY-IN MSA
# 30                         31. Kansas City, MO-KS MSA
# 31                               32. Columbus, OH MSA
# 32           33. Indianapolis-Carmel-Anderson, IN MSA
# 33                       34. Cleveland-Elyria, OH MSA
# 34         35. San Jose-Sunnyvale-Santa Clara, CA MSA
# 35  36. Nashville-Davidson–Murfreesboro–Franklin, ...
# 36  37. Virginia Beach-Norfolk-Newport News, VA-NC...
# 37                  38. Providence-Warwick, RI-MA MSA
# 38                     39. Milwaukee-Waukesha, WI MSA
# 39                           40. Jacksonville, FL MSA
# 40                          41. Oklahoma City, OK MSA
# 41                           42. Raleigh-Cary, NC MSA
# 42                          43. Memphis, TN-MS-AR MSA
# 43                               44. Richmond, VA MSA
# 44                   45. New Orleans-Metairie, LA MSA
# 45         46. Louisville/Jefferson County, KY-IN MSA
# 46                         47. Salt Lake City, UT MSA
# 47      48. Hartford-East Hartford-Middletown, CT MSA
# 48                  49. Buffalo-Niagara Falls, NY MSA
# 49                      50. Birmingham-Hoover, AL MSA
#
#    Per Capita Personal Income (PCPI) (2019)[2]  \
# 0                                      $79,844
# 1                                      $66,684
# 2                                      $63,500
# 3                                      $58,725
# 4                                      $58,890
# 5                                      $74,385
# 6                                      $60,966
# 7                                      $66,596
# 8                                      $54,557
# 9                                      $48,065
# 10                                     $81,498
# 11                                    $104,291
# 12                                     $42,242
# 13                                     $54,172
# 14                                     $78,073
# 15                                     $64,225
# 16                                     $63,726
# 17                                    $48, 908
# 18                                     $67,236
# 19                                     $56,293
# 20                                     $63,988
# 21                                     $53,916
# 22                                     $45,156
# 23                                     $48,694
# 24                                     $59,921
# 25                                     $58,843
# 26                                     $60,227
# 27                                     $48,806
# 28                                     $61,977
# 29                                     $56,033
# 30                                     $55,009
# 31                                     $52,477
# 32                                     $56,360
# 33                                     $55,451
# 34                                    $114,080
# 35                                     $60,680
# 36                                     $52,011
# 37                                     $56,138
# 38                                     $58,457
# 39                                     $51,421
# 40                                     $48,860
# 41                                     $57,851
# 42                                     $47,985
# 43                                     $58,628
# 44                                     $54,463
# 45                                     $52,134
# 46                                     $54,450
# 47                                     $65,152
# 48                                     $52,331
# 49                                     $53,374
#
#     Rank in PCPI before adjustment Purchasing power of $1.00 (2019)[5]  \
# 0                              4.0                               $0.80
# 1                              8.0                               $0.84
# 2                             14.0                               $0.97
# 3                             22.0                               $0.99
# 4                             20.0                               $0.98
# 5                              6.0                               $0.85
# 6                             16.0                               $0.90
# 7                              9.0                               $0.95
# 8                             32.0                               $1.02
# 9                             47.0                               $1.01
# 10                             3.0                               $0.87
# 11                             2.0                               $0.74
# 12                            50.0                               $0.93
# 13                            35.0                               $1.04
# 14                             5.0                               $0.87
# 15                            11.0                               $0.97
# 16                            13.0                               $0.85
# 17                            43.0                               $1.01
# 18                             7.0                               $0.96
# 19                            27.0                               $1.11
# 20                            12.0                               $0.95
# 21                            43.0                               $1.06
# 22                            49.0                               $1.01
# 23                            46.0                               $1.07
# 24                            19.0                               $0.95
# 25                            21.0                               $0.95
# 26                            18.0                               $1.01
# 27                            45.0                               $1.03
# 28                            15.0                               $1.01
# 29                            29.0                               $1.10
# 30                            31.0                               $1.08
# 31                            40.0                               $1.09
# 32                            26.0                               $1.10
# 33                            30.0                               $1.11
# 34                             1.0                               $0.79
# 35                            17.0                               $1.06
# 36                            37.0                               $1.04
# 37                            28.0                               $1.00
# 38                            24.0                               $1.06
# 39                            36.0                               $1.05
# 40                            44.0                               $1.11
# 41                            25.0                               $1.04
# 42                            48.0                               $1.12
# 43                            23.0                               $1.04
# 44                            33.0                               $1.07
# 45                            38.0                               $1.12
# 46                            34.0                               $1.01
# 47                            10.0                               $0.98
# 48                            39.0                               $1.06
# 49                            41.0                               $1.13
#
#    PCPI after adjustments for purchasing power of dollar  \
# 0                                             $63,875
# 1                                             $56,015
# 2                                             $61,595
# 3                                             $58,138
# 4                                             $57,712
# 5                                             $63,227
# 6                                             $54,869
# 7                                             $63,226
# 8                                             $55,648
# 9                                             $48,546
# 10                                            $70,903
# 11                                            $77,175
# 12                                            $39,285
# 13                                            $56,339
# 14                                            $67,924
# 15                                            $62,298
# 16                                            $54,167
# 17                                            $49,397
# 18                                            $64,547
# 19                                            $63,185
# 20                                            $60,789
# 21                                            $57,151
# 22                                            $45,608
# 23                                            $52,106
# 24                                            $56,925
# 25                                            $55,901
# 26                                            $60,829
# 27                                            $50,270
# 28                                            $62,597
# 29                                            $61,636
# 30                                            $59,406
# 31                                            $57,200
# 32                                            $61,966
# 33                                           $61, 551
# 34                                            $90,123
# 35                                            $64,321
# 36                                            $54,091
# 37                                            $56,138
# 38                                            $62,060
# 39                                            $53,992
# 40                                            $54,235
# 41                                            $60,165
# 42                                            $53,743
# 43                                            $60,973
# 44                                            $58,275
# 45                                            $58,390
# 46                                            $54,995
# 47                                            $63,849
# 48                                            $55,471
# 49                                            $60,313
#
#     Rank in PCPI after adjustment
# 0                             7.0
# 1                            34.0
# 2                            18.0
# 3                            27.0
# 4                            28.0
# 5                             9.0
# 6                            39.0
# 7                            10.0
# 8                            36.0
# 9                            48.0
# 10                            3.0
# 11                            2.0
# 12                           50.0
# 13                           32.0
# 14                            4.0
# 15                           13.0
# 16                           41.0
# 17                           47.0
# 18                            5.0
# 19                           11.0
# 20                           21.0
# 21                           30.0
# 22                           49.0
# 23                           45.0
# 24                           31.0
# 25                           35.0
# 26                           20.0
# 27                           46.0
# 28                           12.0
# 29                           16.0
# 30                           24.0
# 31                           29.0
# 32                           15.0
# 33                           17.0
# 34                            1.0
# 35                            6.0
# 36                           42.0
# 37                           33.0
# 38                           14.0
# 39                           43.0
# 40                           40.0
# 41                           23.0
# 42                           44.0
# 43                           19.0
# 44                           26.0
# 45                           25.0
# 46                           38.0
# 47                            8.0
# 48                           37.0
# 49                           22.0

# %% [markdown]
# **#1. Remove 'MSA' from the primary Name Column**

# %% [markdown]
# The first formatting/cleaning task is to remove unecessary strings from the primary name variable. I will have to conduct fuzzy matching to bring in the official CENSUS MSA ID.
#
# This step will improve the success of fuzzy matching.

# %%
# Remove 'MSA' from the name column for consistency and to improve fuzzy match

df['50 largest metropolitan areas'] = df['50 largest metropolitan areas'].str.replace('MSA', '')

# %%
df[['50 largest metropolitan areas']].head(5)
# Out:
#                     50 largest metropolitan areas
# 0  1. New York City-Newark-Jersey City, NY-NJ-PA
# 1          2. Los Angeles-Long Beach-Anaheim, CA
# 2          3. Chicago-Naperville-Elgin, IL-IN-WI
# 3             4. Dallas-Fort Worth-Arlington, TX
# 4        5. Houston-The Woodlands-Sugar Land, TX

# %% [markdown]
# **#2. Remove intigers from the primary Name Column**

# %% [markdown]
# Now I'll do further cleaning of the name column to further improve the success of fuzzy match.

# %%
# Remove intergers '1, 2, 3, etc.' from the name column to improve fuzzy match

df['50 largest metropolitan areas'] = df['50 largest metropolitan areas'].str.replace('\d+', '', regex=True)

# Remove the initial '.' from the start of the string
df['50 largest metropolitan areas'] = df['50 largest metropolitan areas'].str.replace('.', '', regex=True)

# %%
df[['50 largest metropolitan areas']].head(5)
# Out:
#                   50 largest metropolitan areas
# 0   New York City-Newark-Jersey City, NY-NJ-PA
# 1           Los Angeles-Long Beach-Anaheim, CA
# 2           Chicago-Naperville-Elgin, IL-IN-WI
# 3              Dallas-Fort Worth-Arlington, TX
# 4         Houston-The Woodlands-Sugar Land, TX

# %% [markdown]
# **#3. Clean up the Column Names**

# %% [markdown]
# This next step is improve the readability of the columns and make them easier for use in downstream tasks.

# %%
# Clean up some of the column names to make them easier to read

df.rename(columns={
    '50 largest metropolitan areas': 'Metropolitan Area',
    'Per Capita Personal Income (PCPI) (2019)[2]': 'Per Capita Personal Income (PCPI) (2019)',
    'Purchasing power of $1.00 (2019)[5]': 'Purchasing power of $1.00 (2019)'
}, inplace=True)

# %%
df.head(5)
# Out:
#                               Metropolitan Area  \
# 0   New York City-Newark-Jersey City, NY-NJ-PA
# 1           Los Angeles-Long Beach-Anaheim, CA
# 2           Chicago-Naperville-Elgin, IL-IN-WI
# 3              Dallas-Fort Worth-Arlington, TX
# 4         Houston-The Woodlands-Sugar Land, TX
#
#   Per Capita Personal Income (PCPI) (2019)  Rank in PCPI before adjustment  \
# 0                                  $79,844                             4.0
# 1                                  $66,684                             8.0
# 2                                  $63,500                            14.0
# 3                                  $58,725                            22.0
# 4                                  $58,890                            20.0
#
#   Purchasing power of $1.00 (2019)  \
# 0                            $0.80
# 1                            $0.84
# 2                            $0.97
# 3                            $0.99
# 4                            $0.98
#
#   PCPI after adjustments for purchasing power of dollar  \
# 0                                            $63,875
# 1                                            $56,015
# 2                                            $61,595
# 3                                            $58,138
# 4                                            $57,712
#
#    Rank in PCPI after adjustment
# 0                            7.0
# 1                           34.0
# 2                           18.0
# 3                           27.0
# 4                           28.0

# %% [markdown]
# **#4. Perform fuzzy matching to match Metropolitan Area to the official Census MSA Name**

# %% [markdown]
# This step needs to be done because the web data has its own naming convetion for MSA. In order for this data source to be tied to the other data sources, the Census naming convention and IDs for MSA need to be imported and matched to the naming convention in the web data.
#
# To do this I need to use a mapping from the U.S. Census and conduct a fuzzy match to the naming convention 'Region Name' column of the flat file.

# %%
# Importing US Census mapping file
dfmapping = pd.read_excel("MappingFile0.xlsx")

dfmapping.head()
# Out:
#    CBSA Code    CBSA Title
# 0      10100  Aberdeen, SD
# 1      10100  Aberdeen, SD
# 2      10140  Aberdeen, WA
# 3      10180   Abilene, TX
# 4      10180   Abilene, TX

# %%
# Dedupping mapping file
dfmappingV2 = dfmapping.drop_duplicates()

dfmappingV2.head()
# Out:
#    CBSA Code    CBSA Title
# 0      10100  Aberdeen, SD
# 2      10140  Aberdeen, WA
# 3      10180   Abilene, TX
# 6      10220       Ada, OK
# 7      10300    Adrian, MI

# %%
from thefuzz import fuzz, process

# extracting the relevant columns for fuzzy matching
column_a = dfmappingV2['CBSA Title']
column_b = df['Metropolitan Area'] 

# Initialize a list to store the matches
matches = []

# Iterate over each item in column_b
for b in column_b:
    best_match = None
    highest_score = 0

    # Compare with each item in column_a
    for a in column_a:
        score = fuzz.token_sort_ratio(b, a)

        # Update the best match if this score is higher than the current highest
        if score > highest_score:
            best_match = a
            highest_score = score

    # Append the best match and its score to the matches list
    matches.append((b, best_match, highest_score))

# Create a DataFrame from the matches
matches_web_df = pd.DataFrame(matches, columns=['Metropolitan Area', 'CBSA Title', 'Score'])

# %%
# Now matches_df contains the best matches based on the highest ratio
matches_web_df.sort_values(by='Score', ascending=True)
# Out:
#                                  Metropolitan Area  \
# 26     Pittsburgh-New Castle-Weirton, PA-OH-WV CSA
# 50                                   United States
# 10    Boston-Worcester-Providence, MA-RI-NH-CT CSA
# 48                      Buffalo-Niagara Falls, NY
# 18                     Denver-Aurora-Lakewood, CO
# 32               Indianapolis-Carmel-Anderson, IN
# 8            Atlanta-Sandy Springs-Alpharetta, GA
# 27               Las Vegas-Henderson-Paradise, NV
# 28               Austin-Round Rock-Georgetown, TX
# 11             San Francisco-Oakland-Berkeley, CA
# 47          Hartford-East Hartford-Middletown, CT
# 33                           Cleveland-Elyria, OH
# 36     Virginia Beach-Norfolk-Newport News, VA-NC
# 49                          Birmingham-Hoover, AL
# 4            Houston-The Woodlands-Sugar Land, TX
# 46                             Salt Lake City, UT
# 0      New York City-Newark-Jersey City, NY-NJ-PA
# 2              Chicago-Naperville-Elgin, IL-IN-WI
# 17             Tampa-St Petersburg-Clearwater, FL
# 1              Los Angeles-Long Beach-Anaheim, CA
# 3                 Dallas-Fort Worth-Arlington, TX
# 45             Louisville/Jefferson County, KY-IN
# 44                       New Orleans-Metairie, LA
# 43                                   Richmond, VA
# 42                              Memphis, TN-MS-AR
# 41                               Raleigh-Cary, NC
# 40                              Oklahoma City, OK
# 39                               Jacksonville, FL
# 38                         Milwaukee-Waukesha, WI
# 37                      Providence-Warwick, RI-MA
# 5    Washington-Arlington-Alexandria, DC-VA-MD-WV
# 35   Nashville-Davidson–Murfreesboro–Franklin, TN
# 34             San Jose-Sunnyvale-Santa Clara, CA
# 6       Miami-Fort Lauderdale-West Palm Beach, FL
# 7     Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 15         Minneapolis-St Paul-Bloomington, MN-WI
# 19                                St Louis, MO-IL
# 20                  Baltimore-Columbia-Towson, MD
# 21              Charlotte-Concord-Gastonia, NC-SC
# 22                  Orlando-Kissimmee-Sanford, FL
# 23                  San Antonio-New Braunfels, TX
# 16             San Diego-Chula Vista-Carlsbad, CA
# 24            Portland-Vancouver-Hillsboro, OR-WA
# 13                    Detroit–Warren–Dearborn, MI
# 12           Riverside-San Bernardino-Ontario, CA
# 9                       Phoenix-Mesa-Chandler, AZ
# 29                           Cincinnati, OH-KY-IN
# 30                             Kansas City, MO-KS
# 31                                   Columbus, OH
# 14                    Seattle-Tacoma-Bellevue, WA
# 25                Sacramento-Roseville-Folsom, CA
#
#                                         CBSA Title  Score
# 26                      Washington Court House, OH     48
# 50                                      Athens, TN     55
# 10                       Providence-Warwick, RI-MA     60
# 48                         Buffalo-Cheektowaga, NY     61
# 18                    Denver-Aurora-Centennial, CO     62
# 32               Indianapolis-Carmel-Greenwood, IN     70
# 8                Atlanta-Sandy Springs-Roswell, GA     72
# 27         Las Vegas-Henderson-North Las Vegas, NV     72
# 28                Austin-Round Rock-San Marcos, TX     74
# 11               San Francisco-Oakland-Fremont, CA     74
# 47        Hartford-West Hartford-East Hartford, CT     77
# 33                                   Cleveland, OH     77
# 36        Virginia Beach-Chesapeake-Norfolk, VA-NC     78
# 49                                  Birmingham, AL     79
# 4               Houston-Pasadena-The Woodlands, TX     82
# 46                       Salt Lake City-Murray, UT     83
# 0               New York-Newark-Jersey City, NY-NJ     89
# 2                  Chicago-Naperville-Elgin, IL-IN     95
# 17             Tampa-St. Petersburg-Clearwater, FL    100
# 1               Los Angeles-Long Beach-Anaheim, CA    100
# 3                  Dallas-Fort Worth-Arlington, TX    100
# 45              Louisville/Jefferson County, KY-IN    100
# 44                        New Orleans-Metairie, LA    100
# 43                                    Richmond, VA    100
# 42                               Memphis, TN-MS-AR    100
# 41                                Raleigh-Cary, NC    100
# 40                               Oklahoma City, OK    100
# 39                                Jacksonville, FL    100
# 38                          Milwaukee-Waukesha, WI    100
# 37                       Providence-Warwick, RI-MA    100
# 5     Washington-Arlington-Alexandria, DC-VA-MD-WV    100
# 35  Nashville-Davidson--Murfreesboro--Franklin, TN    100
# 34              San Jose-Sunnyvale-Santa Clara, CA    100
# 6        Miami-Fort Lauderdale-West Palm Beach, FL    100
# 7      Philadelphia-Camden-Wilmington, PA-NJ-DE-MD    100
# 15         Minneapolis-St. Paul-Bloomington, MN-WI    100
# 19                                St. Louis, MO-IL    100
# 20                   Baltimore-Columbia-Towson, MD    100
# 21               Charlotte-Concord-Gastonia, NC-SC    100
# 22                   Orlando-Kissimmee-Sanford, FL    100
# 23                   San Antonio-New Braunfels, TX    100
# 16              San Diego-Chula Vista-Carlsbad, CA    100
# 24             Portland-Vancouver-Hillsboro, OR-WA    100
# 13                     Detroit-Warren-Dearborn, MI    100
# 12            Riverside-San Bernardino-Ontario, CA    100
# 9                        Phoenix-Mesa-Chandler, AZ    100
# 29                            Cincinnati, OH-KY-IN    100
# 30                              Kansas City, MO-KS    100
# 31                                    Columbus, OH    100
# 14                     Seattle-Tacoma-Bellevue, WA    100
# 25                 Sacramento-Roseville-Folsom, CA    100

# %%
# creating a csv to manually evaluate the lower scored matches
matches_web_df.to_csv("fuzzy_matchedV3_webdata.csv", index=False)

# %% [markdown]
# The fuzzy match was able to succesfully match 94% of the records. The remaining records will need to be manually evaluated for accuracy. I will perform this evaluation offline in excel and will load the finished csv once this process is completed.

# %% [markdown]
# **#5. Add MSA ID using the finalized mapping file started by fuzzy match**

# %%
# Importing the completed fuzzy matched file with manual verifications
manualFuzzV3df = pd.read_csv("fuzzy_matched_manual_verified_V3_webdata.csv")

manualFuzzV3df.head()
# Out:
#                                Metropolitan Area  \
# 0    Pittsburgh-New Castle-Weirton, PA-OH-WV CSA
# 1   Boston-Worcester-Providence, MA-RI-NH-CT CSA
# 2                     Buffalo-Niagara Falls, NY
# 3                    Denver-Aurora-Lakewood, CO
# 4              Indianapolis-Carmel-Anderson, IN
#
#                           CBSA Title  Score
# 0                     Pittsburgh, PA     48
# 1     Boston-Cambridge-Newton, MA-NH     60
# 2            Buffalo-Cheektowaga, NY     61
# 3       Denver-Aurora-Centennial, CO     62
# 4  Indianapolis-Carmel-Greenwood, IN     70

# %%
# Merge dfmappingV2 with manualFuzzdf
merged_mapping = pd.merge(dfmappingV2, manualFuzzV3df, on='CBSA Title', how='right')

# Check the merged data
merged_mapping.head()
# Out:
#    CBSA Code                         CBSA Title  \
# 0      38300                     Pittsburgh, PA
# 1      14460     Boston-Cambridge-Newton, MA-NH
# 2      15380            Buffalo-Cheektowaga, NY
# 3      19740       Denver-Aurora-Centennial, CO
# 4      26900  Indianapolis-Carmel-Greenwood, IN
#
#                                Metropolitan Area  Score
# 0    Pittsburgh-New Castle-Weirton, PA-OH-WV CSA     48
# 1   Boston-Worcester-Providence, MA-RI-NH-CT CSA     60
# 2                     Buffalo-Niagara Falls, NY      61
# 3                    Denver-Aurora-Lakewood, CO      62
# 4              Indianapolis-Carmel-Anderson, IN      70

# %%
# Merge the above result with the cleaned web-data df
final_df = pd.merge(df, merged_mapping, left_on='Metropolitan Area', right_on='Metropolitan Area', how='left')

# Check the final merged DataFrame
final_df.head()
# Out:
#                               Metropolitan Area  \
# 0   New York City-Newark-Jersey City, NY-NJ-PA
# 1           Los Angeles-Long Beach-Anaheim, CA
# 2           Chicago-Naperville-Elgin, IL-IN-WI
# 3              Dallas-Fort Worth-Arlington, TX
# 4         Houston-The Woodlands-Sugar Land, TX
#
#   Per Capita Personal Income (PCPI) (2019)  Rank in PCPI before adjustment  \
# 0                                  $79,844                             4.0
# 1                                  $66,684                             8.0
# 2                                  $63,500                            14.0
# 3                                  $58,725                            22.0
# 4                                  $58,890                            20.0
#
#   Purchasing power of $1.00 (2019)  \
# 0                            $0.80
# 1                            $0.84
# 2                            $0.97
# 3                            $0.99
# 4                            $0.98
#
#   PCPI after adjustments for purchasing power of dollar  \
# 0                                            $63,875
# 1                                            $56,015
# 2                                            $61,595
# 3                                            $58,138
# 4                                            $57,712
#
#    Rank in PCPI after adjustment  CBSA Code  \
# 0                            7.0    35620.0
# 1                           34.0    31080.0
# 2                           18.0    16980.0
# 3                           27.0    19100.0
# 4                           28.0    26420.0
#
#                            CBSA Title  Score
# 0  New York-Newark-Jersey City, NY-NJ   89.0
# 1  Los Angeles-Long Beach-Anaheim, CA  100.0
# 2     Chicago-Naperville-Elgin, IL-IN   95.0
# 3     Dallas-Fort Worth-Arlington, TX  100.0
# 4  Houston-Pasadena-The Woodlands, TX   82.0

# %%
# Dropping the 'Score' column since it's not needed in the final dataset.
final_df.drop(columns=['Score'], inplace=True)

final_df.head()
# Out:
#                               Metropolitan Area  \
# 0   New York City-Newark-Jersey City, NY-NJ-PA
# 1           Los Angeles-Long Beach-Anaheim, CA
# 2           Chicago-Naperville-Elgin, IL-IN-WI
# 3              Dallas-Fort Worth-Arlington, TX
# 4         Houston-The Woodlands-Sugar Land, TX
#
#   Per Capita Personal Income (PCPI) (2019)  Rank in PCPI before adjustment  \
# 0                                  $79,844                             4.0
# 1                                  $66,684                             8.0
# 2                                  $63,500                            14.0
# 3                                  $58,725                            22.0
# 4                                  $58,890                            20.0
#
#   Purchasing power of $1.00 (2019)  \
# 0                            $0.80
# 1                            $0.84
# 2                            $0.97
# 3                            $0.99
# 4                            $0.98
#
#   PCPI after adjustments for purchasing power of dollar  \
# 0                                            $63,875
# 1                                            $56,015
# 2                                            $61,595
# 3                                            $58,138
# 4                                            $57,712
#
#    Rank in PCPI after adjustment  CBSA Code  \
# 0                            7.0    35620.0
# 1                           34.0    31080.0
# 2                           18.0    16980.0
# 3                           27.0    19100.0
# 4                           28.0    26420.0
#
#                            CBSA Title
# 0  New York-Newark-Jersey City, NY-NJ
# 1  Los Angeles-Long Beach-Anaheim, CA
# 2     Chicago-Naperville-Elgin, IL-IN
# 3     Dallas-Fort Worth-Arlington, TX
# 4  Houston-Pasadena-The Woodlands, TX

# %% [markdown]
# I now have the final version of the web data. This data source is rather simple and did not require much processing. However, here are the transformations that were conducted to clean and prep the data:
#
# *In conclusion these were the transformations conducted to the data:*
# - Cleaned the values in 'Metropolitan Area' by removing certain strings.
# - Cleaned the values in 'Metropolitan Area' by removing integersa and certain special characters.
# - Cleaned certain column names to improve readability and downstream use.
# - Performed fuzzy match on 'Metropolitan Area' to Census MSA Name ('CBSA Title')
# - Used the matched values of 'Metropolitan Area' to import Census MSA ID ('CBSA Code')
#
# The MSA ID (CBSA Code) is now included in the final file. The CBSA Code will act as the FK that will tie to the other data sources.

# %%
# creating a csv of the final version of the flat file
final_df.to_csv("web_data_final_version.csv", index=False)
