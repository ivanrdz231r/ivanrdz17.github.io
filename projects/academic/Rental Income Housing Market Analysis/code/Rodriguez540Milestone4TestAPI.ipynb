# %% [markdown]
# # Project: Milestone 4

# %% [markdown]
# ## Connecting to an API/Pulling in the Data and Cleaning/Formatting

# %% [markdown]
# ***Instructions)***
#
# Perform at least 5 data transformation and/or cleansing steps to your API data. The below examples are not required - they are just potential transformations you could do. If your data doesn't work for these scenarios, complete different transformations. You can do the same transformation multiple times if you needed to clean your data. The goal is a clean dataset at the end of the milestone.
#
# - Replace Headers
# - Format data into a more readable format
# - Identify outliers and bad data
# - Find duplicates
# - Fix casing or inconsistent values
# - Conduct Fuzzy Matching
#
# Make sure you clearly label each transformation (Step #1, Step #2, etc.) in your code and describe what it is doing in 1-2 sentences. You can submit a Jupyter Notebook or a PDF of your code. If you submit a .py file you need to also include a PDF or attachment of your results.

# %% [markdown]
# ***Answer)***

# %% [markdown]
# **#0. Intro Work**

# %% [markdown]
# First I must write my API Key and Secret to a JSON file

# %%
import json
import pprint
import getpass

# defining the data (including the API Key and the Secret Key)
data = {
    "test_api_key": "---",
    "test_secret": "---"  # Adding the test_secret field
}

# specifying the JSON file name
filename = 'hc_test_api_key.json'

# writing the data to a JSON file
with open(filename, 'w') as file:
    json.dump(data, file, indent=4)

# %%
# This JSON file has my APIkey
with open('hc_test_api_key.json') as f:
    keys = json.load(f)
    test_key = keys['test_api_key']
    test_secret = keys['test_secret']

# %%
# api test url
test_url = 'https://api.housecanary.com/v2/property/test_addresses?'

# %% [markdown]
# These test addresses are used to make test calls to the API

# %%
import requests

# response chunk
response = requests.get(test_url, auth=(test_key, test_secret))

test_addresses = response.json()

pprint.pprint(test_addresses)
# Out:
# [{'address': '517 N Chugach St', 'zipcode': '99645'},
#  {'address': '12731 Schooner Dr', 'zipcode': '99515'},
#  {'address': '87 Misty Forest Dr', 'zipcode': '36869'},
#  {'address': '5212 Short Leaf Ln', 'zipcode': '35071'},
#  {'address': '209 N Highway 45', 'zipcode': '72916'},
#  {'address': '1207 Cardinal Rd', 'zipcode': '72401'},
#  {'address': '10004 E Vogel Ave', 'zipcode': '85258'},
#  {'address': '321 E Marlette Ave', 'zipcode': '85012'},
#  {'address': '4010 Martis St', 'zipcode': '95691'},
#  {'address': '2439 Russell St', 'zipcode': '94705'},
#  {'address': '5647 Calgary St', 'zipcode': '80547'},
#  {'address': '6823 Ridgeway Cir', 'zipcode': '80134'},
#  {'address': '4 Northbridge', 'zipcode': '06416'},
#  {'address': '66 Fairfield St', 'zipcode': '06515'},
#  {'address': '3367 18th St NW', 'zipcode': '20010'},
#  {'address': '4806 7th St NE', 'zipcode': '20017'},
#  {'address': '18 Old Fence Ln', 'zipcode': '19702'},
#  {'address': '2846 Leipsic Rd', 'zipcode': '19901'},
#  {'address': '8691 Flowersong Cv', 'zipcode': '33473'},
#  {'address': '813 27th Street Ct E', 'zipcode': '34208'},
#  {'address': '602 E 50th St', 'zipcode': '31405'},
#  {'address': '313 E Hobson St', 'zipcode': '31791'},
#  {'address': '679 S Kihei Rd Apt A204', 'zipcode': '96753'},
#  {'address': '86-228 Moelua St', 'zipcode': '96792'},
#  {'address': '107 N 3rd St', 'zipcode': '50629'},
#  {'address': '33895 115th St', 'zipcode': '51034'},
#  {'address': '2405 5th St', 'zipcode': '83501'},
#  {'address': '128 N 11th Ave', 'zipcode': '83201'},
#  {'address': '333 N Canal St Apt 2901', 'zipcode': '60606'},
#  {'address': '1806 S Morgan St', 'zipcode': '60608'},
#  {'address': '805 S Shipley St', 'zipcode': '47302'},
#  {'address': '1356 Crisman Rd', 'zipcode': '46368'},
#  {'address': '201 Brookstone Dr', 'zipcode': '66502'},
#  {'address': '110 S 3rd St', 'zipcode': '66536'},
#  {'address': '101 Stoney Ridge Ct', 'zipcode': '41097'},
#  {'address': '1265 Walnut Ln', 'zipcode': '42431'},
#  {'address': '825 Bayou Paul Ln', 'zipcode': '70776'},
#  {'address': '966 Bohne Rd', 'zipcode': '70767'},
#  {'address': '149 Hope St', 'zipcode': '01301'},
#  {'address': '4 Village Dr', 'zipcode': '01752'},
#  {'address': '43 Andora Dr', 'zipcode': '21921'},
#  {'address': '2400 Beaver Crossing Rd', 'zipcode': '21040'},
#  {'address': '119 Torrey Rd', 'zipcode': '04274'},
#  {'address': '168 Brook Rd', 'zipcode': '04105'},
#  {'address': '3466 Erie Shore Dr', 'zipcode': '48162'},
#  {'address': '4647 Genesee Rd', 'zipcode': '48446'},
#  {'address': '2718 16th Ave S', 'zipcode': '55407'},
#  {'address': '902 S 10th St', 'zipcode': '55041'},
#  {'address': '1040 Queen Ann Dr', 'zipcode': '65201'},
#  {'address': '66 Linden Dr', 'zipcode': '65737'},
#  {'address': '134 Wade Rd', 'zipcode': '39044'},
#  {'address': '1331 Alamo St', 'zipcode': '39213'},
#  {'address': '5049 River Lakes Pkwy', 'zipcode': '59937'},
#  {'address': '1533 Walnut St', 'zipcode': '59601'},
#  {'address': '2537 Chapel Hill Rd', 'zipcode': '27707'},
#  {'address': '201 Aycock Ave', 'zipcode': '28792'},
#  {'address': '225 E Wachter Ave', 'zipcode': '58504'},
#  {'address': '2418 W Fallcreek Ct', 'zipcode': '58201'},
#  {'address': '1622 Main St', 'zipcode': '68048'},
#  {'address': '70 Cottonwood Dr', 'zipcode': '68601'},
#  {'address': '16 Thomas Ave', 'zipcode': '03076'},
#  {'address': '3 Legacy Dr', 'zipcode': '03106'},
#  {'address': '210 Sunnybrook Rd', 'zipcode': '08007'},
#  {'address': '135 Headley Ter', 'zipcode': '07083'},
#  {'address': '4221 Venetian Loop', 'zipcode': '88011'},
#  {'address': '4705 Skyway Ct SW', 'zipcode': '87105'},
#  {'address': '7904 Verde Springs Dr', 'zipcode': '89128'},
#  {'address': '4832 Meadow Springs Dr', 'zipcode': '89509'},
#  {'address': '736 Camp St', 'zipcode': '13440'},
#  {'address': '260 Oliver St', 'zipcode': '14120'},
#  {'address': '7551 Southland Dr', 'zipcode': '44060'},
#  {'address': '1718 Darst Ave', 'zipcode': '45403'},
#  {'address': '11557 SE Taylor St', 'zipcode': '97216'},
#  {'address': '1682 Nunnwood Ln', 'zipcode': '97527'},
#  {'address': '119 Brewster Way', 'zipcode': '18301'},
#  {'address': '114 Brandywine Dr', 'zipcode': '15317'},
#  {'address': '20 Mayfield Rd', 'zipcode': '02806'},
#  {'address': '27 Sunset Dr', 'zipcode': '02813'},
#  {'address': '6 Ivory Ct', 'zipcode': '29687'},
#  {'address': '221 S Rudolph St', 'zipcode': '29138'},
#  {'address': '6216 W Foxdale St', 'zipcode': '57107'},
#  {'address': '802 Rosilee Ln', 'zipcode': '57701'},
#  {'address': '355 Rayon Dr', 'zipcode': '37138'},
#  {'address': '3121 Highway 100', 'zipcode': '37033'},
#  {'address': '22905 Cielo Vis', 'zipcode': '78255'},
#  {'address': '126 Oak Forest Dr', 'zipcode': '78612'},
#  {'address': '3003 Porter Ave', 'zipcode': '84403'},
#  {'address': '378 E 950 N', 'zipcode': '84074'},
#  {'address': '1111 Oronoco St Unit 441', 'zipcode': '22314'},
#  {'address': '14320 Happy Hill Rd', 'zipcode': '23831'},
#  {'address': '216 Goose Pond Rd', 'zipcode': '05454'},
#  {'address': '78 Terrace St', 'zipcode': '05602'},
#  {'address': '1701 Trio Ln', 'zipcode': '99362'},
#  {'address': '1102 Fellows Dr', 'zipcode': '98908'},
#  {'address': 'N557 Westview Dr', 'zipcode': '53066'},
#  {'address': 'N5976 E River Rd', 'zipcode': '54110'},
#  {'address': '500 Watkins St', 'zipcode': '26354'},
#  {'address': '105 Beech Dr', 'zipcode': '25425'},
#  {'address': '2462 Centennial Village Dr', 'zipcode': '82609'},
#  {'address': '3508 Fire Side Dr', 'zipcode': '82001'},
#  {'address': '4334 Oasis Valley Ave', 'zipcode': '89085'},
#  {'address': '11410 W Hadley St', 'zipcode': '85323'},
#  {'address': '8028 Meadow Falls St', 'zipcode': '89085'},
#  {'address': '11281 W Buchanan St', 'zipcode': '85323'},
#  {'address': '11305 W Buchanan St', 'zipcode': '85323'},
#  {'address': '11174 W Tonto St', 'zipcode': '85323'},
#  {'address': '11250 W Lincoln St', 'zipcode': '85323'},
#  {'address': '421 S 114th Ave', 'zipcode': '85323'},
#  {'address': '11370 W Lincoln St', 'zipcode': '85323'},
#  {'address': '11330 W Buchanan St', 'zipcode': '85323'},
#  {'address': '11305 W Harrison St', 'zipcode': '85323'},
#  {'address': '4352 Desert Park Ave', 'zipcode': '89085'},
#  {'address': '4314 Mesa Landing Ave', 'zipcode': '89085'},
#  {'address': '814 S 112th Ave', 'zipcode': '85323'},
#  {'address': '11357 W Lincoln St', 'zipcode': '85323'},
#  {'address': '8328 Mesa Bloom St', 'zipcode': '89085'},
#  {'address': '4339 Oasis Hill Ave', 'zipcode': '89085'},
#  {'address': '11310 W Tonto St', 'zipcode': '85323'},
#  {'address': '8264 Mesa Bloom St', 'zipcode': '89085'},
#  {'address': '8034 Meadow Pasture St', 'zipcode': '89085'}]

# %%
# Now that we've retrieved some test addresses, we can use one of them
# to test out the HouseCanary API endpoints.
# Let's try one of the Analytics API endpoints.

# we'll just take the first address from the list.
sample_address = test_addresses[0]

url = 'https://api.housecanary.com/v2/property/details'

params = {'address': sample_address['address'],
          'zipcode': sample_address['zipcode']}

response = requests.get(url, params=params, auth=(test_key, test_secret))
response_output = response.json()

# We can see what the url looks like
print(response.url)
pprint.pprint(response_output)
# Out:
# https://api.housecanary.com/v2/property/details?address=517+N+Chugach+St&zipcode=99645
# [{'address_info': {'address': '517 N Chugach St',
#                    'address_full': '517 N Chugach St Palmer AK 99645',
#                    'block_id': '021700012011002',
#                    'blockgroup_id': '021700012011',
#                    'city': 'Palmer',
#                    'county_fips': '02170',
#                    'geo_precision': 'rooftop',
#                    'lat': 61.6128922,
#                    'lng': -149.1104737,
#                    'metrodiv': None,
#                    'msa': '11260',
#                    'slug': '517-N-Chugach-St-Palmer-AK-99645',
#                    'state': 'AK',
#                    'status': {'changes': ['Locality (city, municipality) added '
#                                           'or changed',
#                                           'State added or changed'],
#                               'details': ['Address fully verified',
#                                           'Melissa Used'],
#                               'errors': [],
#                               'match': True,
#                               'requested_item': {'address': '517 N Chugach St',
#                                                  'address_id': 27076470,
#                                                  'zipcode': '99645'}},
#                    'unit': None,
#                    'zipcode': '99645',
#                    'zipcode_plus4': '6039'},
#   'property/details': {'api_code': 0,
#                        'api_code_description': 'ok',
#                        'result': {'assessment': {'apn': '5020B02L020',
#                                                  'assessment_year': 2023,
#                                                  'tax_amount': 2668.94,
#                                                  'tax_year': 2023,
#                                                  'total_assessed_value': 234200.0},
#                                   'property': {'air_conditioning': None,
#                                                'attic': None,
#                                                'basement': 'no_basement',
#                                                'building_area_sq_ft': 1710,
#                                                'building_condition_score': None,
#                                                'building_quality_score': None,
#                                                'construction_type': None,
#                                                'exterior_walls': None,
#                                                'fireplace': False,
#                                                'full_bath_count': None,
#                                                'garage_parking_of_cars': None,
#                                                'garage_type_parking': 'garage',
#                                                'heating': 'gas',
#                                                'heating_fuel_type': 'gas',
#                                                'no_of_buildings': None,
#                                                'no_of_stories': None,
#                                                'number_of_bedrooms': None,
#                                                'number_of_units': None,
#                                                'partial_bath_count': None,
#                                                'pool': None,
#                                                'property_type': 'Single Family '
#                                                                 'Residential',
#                                                'roof_cover': None,
#                                                'roof_type': None,
#                                                'sewer': 'municipal',
#                                                'site_area_acres': 0.24,
#                                                'style': None,
#                                                'subdivision': 'RIVERSIDE',
#                                                'total_bath_count': None,
#                                                'total_number_of_rooms': None,
#                                                'water': 'municipal',
#                                                'year_built': 1982,
#                                                'zoning': None}}}}]

# %%
# Let's try the Value Report API.

url = 'https://api.housecanary.com/v2/property/value_report'

params = {'address': sample_address['address'],
          'zipcode': sample_address['zipcode'],
          'format': 'json'}

response = requests.get(url, params=params, auth=(test_key, test_secret))

print(response.url)
pprint.pprint(response.json())

# use response.json() to get the Value Report json. The content is too long to display here.
# Out:
# https://api.housecanary.com/v2/property/value_report?address=517+N+Chugach+St&zipcode=99645&format=json
# {'active_listings': [{'active_days_on_market': None,
#                       'address_id': 2865554,
#                       'address_slug': '9830-E-Tern-Dr-Palmer-AK-99645',
#                       'age': 40,
#                       'apn': '1631B03L048',
#                       'basement': False,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700011003',
#                       'cerberus_id': '502446d5c588cc3b',
#                       'city': 'Palmer',
#                       'comp': 4,
#                       'construction_type': 'Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 415742,
#                       'days_on_market': 23.0,
#                       'distance_miles': 3.0620296887918155,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Paved,Attached,No Carport',
#                       'geo_location': {'latitude': 61.61859,
#                                        'longitude': -149.20299},
#                       'gross_living_area_sqft': 1748,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 415742,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-01',
#                       'last_list_price': 415000,
#                       'last_list_price_adjusted': 371784,
#                       'listing_entity_id': '65bc04bc5ec5cb3b7f20d193',
#                       'listing_id': '24-1003',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-01',
#                       'net_dollar_adjustment': -43215.67,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '2004-11-15',
#                       'sales_price': None,
#                       'similarity_level': 'moderate',
#                       'similarity_level_adjusted': 'moderate',
#                       'similarity_score': 85,
#                       'similarity_score_adjusted': 83,
#                       'site_area_sqft': 40075,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '9830 E Tern Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700011003013',
#                       'tract_id': '02170001100',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 1984,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 6483785,
#                       'address_slug': '3975-S-Tustin-Dr-Palmer-AK-99645',
#                       'age': 39,
#                       'apn': '1279B02L008',
#                       'basement': False,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700013002',
#                       'cerberus_id': 'e5f3dabb7e91fa48',
#                       'city': 'Palmer',
#                       'comp': 24,
#                       'construction_type': 'Log ,Log Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 422424,
#                       'days_on_market': 223.0,
#                       'distance_miles': 5.84241782152921,
#                       'flips': None,
#                       'garage_num_cars': None,
#                       'garage_type': 'No Garage,No Carport',
#                       'geo_location': {'latitude': 61.53759,
#                                        'longitude': -149.0293901},
#                       'gross_living_area_sqft': 1566,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 422424,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2023-07-01',
#                       'last_list_price': 425000,
#                       'last_list_price_adjusted': 406376,
#                       'listing_entity_id': '64a91eec0ed6d206228756f6',
#                       'listing_id': '23-7644',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-09',
#                       'net_dollar_adjustment': -16047.16,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'high',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 91,
#                       'similarity_score_adjusted': 71,
#                       'site_area_sqft': 51400,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '3975 S Tustin Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700013002020',
#                       'tract_id': '02170001300',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 1985,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 310136438,
#                       'address_slug': '13251-E-Cayuga-Ave-Palmer-AK-99645',
#                       'age': None,
#                       'apn': '7781B03L002',
#                       'basement': False,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700003001',
#                       'cerberus_id': 'edc995a7fa971a39',
#                       'city': 'Palmer',
#                       'comp': 25,
#                       'construction_type': 'Frame ,Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': None,
#                       'days_on_market': 16.0,
#                       'distance_miles': 4.517298984831869,
#                       'flips': None,
#                       'garage_num_cars': 1,
#                       'garage_type': 'Garage Door Opener,Attached,Heated '
#                                      'Garage,No Carport',
#                       'geo_location': {'latitude': 61.6782875,
#                                        'longitude': -149.1146394},
#                       'gross_living_area_sqft': 1284,
#                       'hc_mls_id': 2,
#                       'housecanary_value': None,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-08',
#                       'last_list_price': 345000,
#                       'last_list_price_adjusted': 265411,
#                       'listing_entity_id': '65c58b30bc46d80149231386',
#                       'listing_id': '24-1241',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-08',
#                       'net_dollar_adjustment': -79588.51,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 74,
#                       'similarity_score_adjusted': 70,
#                       'site_area_sqft': 54014,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': 2,
#                       'street_address': '13251 E Cayuga Ave',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700003001012',
#                       'tract_id': '02170000300',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2024,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 5785579,
#                       'address_slug': '11395-N-Seventeen-Mile-Blvd-Palmer-AK-99645',
#                       'age': 25,
#                       'apn': '1185B01L017',
#                       'basement': False,
#                       'bathrooms': 2.5,
#                       'bedrooms': 3,
#                       'bg_id': '021700002001',
#                       'cerberus_id': 'f343f7666c0f280f',
#                       'city': 'Palmer',
#                       'comp': 31,
#                       'construction_type': 'Frame ,Vinyl Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 438305,
#                       'days_on_market': 10.0,
#                       'distance_miles': 7.935134978902679,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Garage Door Opener,Attached,No Carport',
#                       'geo_location': {'latitude': 61.7121773,
#                                        'longitude': -148.9885254},
#                       'gross_living_area_sqft': 1816,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 438305,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-14',
#                       'last_list_price': 436000,
#                       'last_list_price_adjusted': 361894,
#                       'listing_entity_id': '65d86718ce45e4004fe37ea0',
#                       'listing_id': '24-1408',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-23',
#                       'net_dollar_adjustment': -74105.77,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '2021-11-08',
#                       'sales_price': None,
#                       'similarity_level': 'moderate',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 78,
#                       'similarity_score_adjusted': 69,
#                       'site_area_sqft': 69260,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '11395 N Seventeen Mile Blvd',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700002001017',
#                       'tract_id': '02170000200',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 1999,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 53799448,
#                       'address_slug': '5550-N-Talgach-View-Dr-Wasilla-AK-99654',
#                       'age': 47,
#                       'apn': '1241B01L004',
#                       'basement': False,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700003002',
#                       'cerberus_id': '9f03348fe9914259',
#                       'city': 'Wasilla',
#                       'comp': 34,
#                       'construction_type': 'Concrete ,Frame ,Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 405024,
#                       'days_on_market': 45.0,
#                       'distance_miles': 7.413176822049558,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Garage Door Opener,RV '
#                                      'Access/Parking,Detached,No Carport',
#                       'geo_location': {'latitude': 61.64552,
#                                        'longitude': -149.32574},
#                       'gross_living_area_sqft': 1932,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 405024,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2023-08-28',
#                       'last_list_price': 385000,
#                       'last_list_price_adjusted': 356660,
#                       'listing_entity_id': '64eefe6c4e96b50ffa513d57',
#                       'listing_id': '23-10698',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2023-10-31',
#                       'net_dollar_adjustment': -48363.09,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '2010-06-18',
#                       'sales_price': None,
#                       'similarity_level': 'moderate',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 83,
#                       'similarity_score_adjusted': 69,
#                       'site_area_sqft': 80586,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '5550 N Talgach View Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700003002013',
#                       'tract_id': '02170000300',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 1977,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 318376357,
#                       'address_slug': '2741-N-Northgate-Pl-Wasilla-AK-99654',
#                       'age': None,
#                       'apn': '8252B03L002',
#                       'basement': False,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700010032',
#                       'cerberus_id': '0621b73eab7b57f5',
#                       'city': 'Wasilla',
#                       'comp': 36,
#                       'construction_type': 'Frame ,Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 365929,
#                       'days_on_market': 37.0,
#                       'distance_miles': 7.610806533330061,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Garage Door Opener,Paved,Attached,Heated '
#                                      'Garage,No Carport',
#                       'geo_location': {'latitude': 61.6100464,
#                                        'longitude': -149.3422395},
#                       'gross_living_area_sqft': 1282,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 365929,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-19',
#                       'last_list_price': 372500,
#                       'last_list_price_adjusted': 297545,
#                       'listing_entity_id': '65aaee04551b95342b163bf9',
#                       'listing_id': '24-612',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-19',
#                       'net_dollar_adjustment': -74954.99,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 75,
#                       'similarity_score_adjusted': 67,
#                       'site_area_sqft': 20037,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '2741 N Northgate Pl',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700010032023',
#                       'tract_id': '02170001003',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2024,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 37839187,
#                       'address_slug': '5560-E-Big-Rock-Dr-Wasilla-AK-99654',
#                       'age': 17,
#                       'apn': '5835000L001',
#                       'basement': False,
#                       'bathrooms': 2.5,
#                       'bedrooms': 3,
#                       'bg_id': '021700003003',
#                       'cerberus_id': 'c6163340dadcb5ec',
#                       'city': 'Wasilla',
#                       'comp': 43,
#                       'construction_type': 'Block ,Concrete ,Frame ,Wood '
#                                            'Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 394890,
#                       'days_on_market': 21.0,
#                       'distance_miles': 7.307945232147516,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Garage Door Opener,Paved,RV '
#                                      'Access/Parking,Attached,Heated '
#                                      'Garage,Tuck Under,No Carport',
#                       'geo_location': {'latitude': 61.65391,
#                                        'longitude': -149.31584},
#                       'gross_living_area_sqft': 1794,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 394890,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-03',
#                       'last_list_price': 429900,
#                       'last_list_price_adjusted': 331475,
#                       'listing_entity_id': '65d1494077e5bb0043a22172',
#                       'listing_id': '24-1094',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-16',
#                       'net_dollar_adjustment': -98424.47,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '2016-04-04',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 74,
#                       'similarity_score_adjusted': 66,
#                       'site_area_sqft': 40075,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': 2,
#                       'street_address': '5560 E Big Rock Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700003003025',
#                       'tract_id': '02170000300',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2007,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 5235247,
#                       'address_slug': '9830-E-Breen-St-Palmer-AK-99645',
#                       'age': 10,
#                       'apn': '5839B04L007',
#                       'basement': None,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700003001',
#                       'cerberus_id': 'cb4ddaac0853bba3',
#                       'city': 'Palmer',
#                       'comp': 44,
#                       'construction_type': 'Frame ,Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 465414,
#                       'days_on_market': 14.0,
#                       'distance_miles': 4.084522339575544,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Attached,No Carport',
#                       'geo_location': {'latitude': 61.65324,
#                                        'longitude': -149.20153},
#                       'gross_living_area_sqft': 1958,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 465414,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-12',
#                       'last_list_price': 485000,
#                       'last_list_price_adjusted': 368059,
#                       'listing_entity_id': '65d126410ae82d0031c83f6d',
#                       'listing_id': '24-1349',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-15',
#                       'net_dollar_adjustment': -116940.05,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '2014-05-16',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 69,
#                       'similarity_score_adjusted': 66,
#                       'site_area_sqft': 44866,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': 2,
#                       'street_address': '9830 E Breen St',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700003001036',
#                       'tract_id': '02170000300',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2014,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 318376312,
#                       'address_slug': '2619-N-Northgate-Pl-Wasilla-AK-99654',
#                       'age': None,
#                       'apn': '8252B02L007',
#                       'basement': False,
#                       'bathrooms': 2.5,
#                       'bedrooms': 3,
#                       'bg_id': '021700010032',
#                       'cerberus_id': '1d3f561d3da5f23d',
#                       'city': 'Wasilla',
#                       'comp': 49,
#                       'construction_type': 'Frame ,Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 407864,
#                       'days_on_market': 37.0,
#                       'distance_miles': 7.760998528859418,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Paved,Heated Garage,No Carport',
#                       'geo_location': {'latitude': 61.6089287,
#                                        'longitude': -149.3467407},
#                       'gross_living_area_sqft': 1575,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 407864,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-19',
#                       'last_list_price': 415000,
#                       'last_list_price_adjusted': 309828,
#                       'listing_entity_id': '65aaf16c9a2df5080ba84c18',
#                       'listing_id': '24-616',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-19',
#                       'net_dollar_adjustment': -105171.74,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 72,
#                       'similarity_score_adjusted': 63,
#                       'site_area_sqft': 20037,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '2619 N Northgate Pl',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700010032023',
#                       'tract_id': '02170001003',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2024,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 294027385,
#                       'address_slug': '5660-E-Alder-Dr-Wasilla-AK-99654',
#                       'age': 4,
#                       'apn': '6445B05L008',
#                       'basement': False,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700010032',
#                       'cerberus_id': '313255b580c3f94a',
#                       'city': 'Wasilla',
#                       'comp': 52,
#                       'construction_type': 'Frame ,Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 473943,
#                       'days_on_market': 112.0,
#                       'distance_miles': 6.387270926018206,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Garage Door Opener,Attached,Heated '
#                                      'Garage,No Carport',
#                       'geo_location': {'latitude': 61.6132011,
#                                        'longitude': -149.3050538},
#                       'gross_living_area_sqft': 1854,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 473943,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2023-11-03',
#                       'last_list_price': 475000,
#                       'last_list_price_adjusted': 371610,
#                       'listing_entity_id': '654594768af7ab0059d06542',
#                       'listing_id': '23-13277',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2023-11-03',
#                       'net_dollar_adjustment': -102332.02,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '2021-02-26',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 71,
#                       'similarity_score_adjusted': 63,
#                       'site_area_sqft': 30492,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '5660 E Alder Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700010032019',
#                       'tract_id': '02170001003',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2020,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 86410126,
#                       'address_slug': '8161-E-Cottrell-Campus-Dr-Palmer-AK-99645',
#                       'age': 48,
#                       'apn': '1189B01L003',
#                       'basement': True,
#                       'bathrooms': 2.0,
#                       'bedrooms': 4,
#                       'bg_id': '021700011001',
#                       'cerberus_id': '1b04d26a4f66c2f2',
#                       'city': 'Palmer',
#                       'comp': 53,
#                       'construction_type': 'Concrete ,Frame ,Vinyl Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 428832,
#                       'days_on_market': 94.0,
#                       'distance_miles': 5.029955644949186,
#                       'flips': None,
#                       'garage_num_cars': 3,
#                       'garage_type': 'Circular Driveway,RV '
#                                      'Access/Parking,Detached,Heated Garage,No '
#                                      'Carport',
#                       'geo_location': {'latitude': 61.577534,
#                                        'longitude': -149.24437},
#                       'gross_living_area_sqft': 2580,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 428832,
#                       'is_distressed': True,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2023-11-22',
#                       'last_list_price': 429900,
#                       'last_list_price_adjusted': 352087,
#                       'listing_entity_id': '655e7de2d8b221005208a694',
#                       'listing_id': '23-13762',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2023-11-22',
#                       'net_dollar_adjustment': -76744.46,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 67,
#                       'similarity_score_adjusted': 62,
#                       'site_area_sqft': 39204,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '8161 E Cottrell Campus Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700011001004',
#                       'tract_id': '02170001100',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 1976,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 31333476,
#                       'address_slug': '5471-N-Westfork-Dr-Wasilla-AK-99654',
#                       'age': None,
#                       'apn': '1417B03L012',
#                       'basement': False,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700003002',
#                       'cerberus_id': 'c158e9889280cf92',
#                       'city': 'Wasilla',
#                       'comp': 56,
#                       'construction_type': 'Frame ,Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': None,
#                       'days_on_market': 40.0,
#                       'distance_miles': 7.228173494562012,
#                       'flips': None,
#                       'garage_num_cars': 3,
#                       'garage_type': 'Garage Door Opener,Attached,Heated '
#                                      'Garage,No Carport',
#                       'geo_location': {'latitude': 61.6437874,
#                                        'longitude': -149.3209686},
#                       'gross_living_area_sqft': 1673,
#                       'hc_mls_id': 2,
#                       'housecanary_value': None,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-15',
#                       'last_list_price': 479900,
#                       'last_list_price_adjusted': 366309,
#                       'listing_entity_id': '65b8c2126f82ce0684fc8a90',
#                       'listing_id': '24-457',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-30',
#                       'net_dollar_adjustment': -113590.46,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '2023-09-27',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 70,
#                       'similarity_score_adjusted': 62,
#                       'site_area_sqft': 47044,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '5471 N Westfork Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700003002015',
#                       'tract_id': '02170000300',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2024,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 4132175,
#                       'address_slug': '4439-E-Boulder-Dr-Wasilla-AK-99654',
#                       'age': 16,
#                       'apn': '6708B10L006',
#                       'basement': None,
#                       'bathrooms': 2.0,
#                       'bedrooms': 4,
#                       'bg_id': '021700003003',
#                       'cerberus_id': 'ecd6b9784d0f3fcb',
#                       'city': 'Wasilla',
#                       'comp': 63,
#                       'construction_type': 'Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 364401,
#                       'days_on_market': 19.0,
#                       'distance_miles': 7.896976017100283,
#                       'flips': None,
#                       'garage_num_cars': 1,
#                       'garage_type': 'Garage Door Opener,Attached,No Carport',
#                       'geo_location': {'latitude': 61.6507,
#                                        'longitude': -149.33766},
#                       'gross_living_area_sqft': 2080,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 364401,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-06',
#                       'last_list_price': 369000,
#                       'last_list_price_adjusted': 257903,
#                       'listing_entity_id': '65cbbcae1a3ad707a4b8a7d4',
#                       'listing_id': '24-1146',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-13',
#                       'net_dollar_adjustment': -111096.88,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '2014-09-12',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 70,
#                       'similarity_score_adjusted': 61,
#                       'site_area_sqft': 20908,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '4439 E Boulder Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700003003024',
#                       'tract_id': '02170000300',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2008,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 318376349,
#                       'address_slug': '2723-N-Northgate-Pl-Wasilla-AK-99654',
#                       'age': None,
#                       'apn': '8252B03L001',
#                       'basement': False,
#                       'bathrooms': 2.5,
#                       'bedrooms': 4,
#                       'bg_id': '021700010032',
#                       'cerberus_id': '3c4727908dfbbcda',
#                       'city': 'Wasilla',
#                       'comp': 68,
#                       'construction_type': 'Frame ,Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 454155,
#                       'days_on_market': 37.0,
#                       'distance_miles': 7.629165009771687,
#                       'flips': None,
#                       'garage_num_cars': 3,
#                       'garage_type': 'Garage Door Opener,Paved,Heated '
#                                      'Garage,No Carport',
#                       'geo_location': {'latitude': 61.6098747,
#                                        'longitude': -149.3427887},
#                       'gross_living_area_sqft': 1894,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 454155,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-19',
#                       'last_list_price': 465000,
#                       'last_list_price_adjusted': 337632,
#                       'listing_entity_id': '65ab29a59a2df50b416192f1',
#                       'listing_id': '24-636',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-19',
#                       'net_dollar_adjustment': -127367.42,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 67,
#                       'similarity_score_adjusted': 59,
#                       'site_area_sqft': 20037,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': 2,
#                       'street_address': '2723 N Northgate Pl',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700010032023',
#                       'tract_id': '02170001003',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2024,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 63166219,
#                       'address_slug': '648-W-Daron-Dr-Palmer-AK-99645',
#                       'age': 41,
#                       'apn': '1564B03L007',
#                       'basement': True,
#                       'bathrooms': 3.5,
#                       'bedrooms': 5,
#                       'bg_id': '021700012022',
#                       'cerberus_id': '248252ecabcdc82e',
#                       'city': 'Palmer',
#                       'comp': 72,
#                       'construction_type': 'Unknown',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 408058,
#                       'days_on_market': 146.0,
#                       'distance_miles': 1.2129675747678315,
#                       'flips': None,
#                       'garage_num_cars': 1,
#                       'garage_type': 'Attached,No Carport',
#                       'geo_location': {'latitude': 61.5969429,
#                                        'longitude': -149.1259613},
#                       'gross_living_area_sqft': 2568,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 408058,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2023-10-03',
#                       'last_list_price': 395000,
#                       'last_list_price_adjusted': 321970,
#                       'listing_entity_id': '651fc2670b736c08de067bd8',
#                       'listing_id': '23-12171',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2023-10-06',
#                       'net_dollar_adjustment': -86087.87,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '2022-03-21',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 62,
#                       'similarity_score_adjusted': 59,
#                       'site_area_sqft': 11325,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '648 W Daron Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700012022011',
#                       'tract_id': '02170001202',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 1983,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 46637875,
#                       'address_slug': '7247-N-King-Cove-Dr-Wasilla-AK-99654',
#                       'age': 6,
#                       'apn': '1443B03L002',
#                       'basement': False,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700003002',
#                       'cerberus_id': '55a77fe693c42ec8',
#                       'city': 'Wasilla',
#                       'comp': 73,
#                       'construction_type': 'Frame ,Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 379544,
#                       'days_on_market': 5.0,
#                       'distance_miles': 7.12296890014217,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Garage Door Opener,Paved,RV '
#                                      'Access/Parking,Attached,Heated Garage,No '
#                                      'Carport',
#                       'geo_location': {'latitude': 61.6648979,
#                                        'longitude': -149.2980347},
#                       'gross_living_area_sqft': 1556,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 379544,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-19',
#                       'last_list_price': 390000,
#                       'last_list_price_adjusted': 264682,
#                       'listing_entity_id': '65d781b8ab7db700accef283',
#                       'listing_id': '24-1524',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-22',
#                       'net_dollar_adjustment': -125317.92,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '2019-09-06',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 67,
#                       'similarity_score_adjusted': 59,
#                       'site_area_sqft': 40075,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '7247 N King Cove Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700003002005',
#                       'tract_id': '02170000300',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2018,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 18303094,
#                       'address_slug': '1222-E-Hidden-Ranch-Loop-Palmer-AK-99645',
#                       'age': 9,
#                       'apn': '5678B07L003',
#                       'basement': None,
#                       'bathrooms': 2.5,
#                       'bedrooms': 4,
#                       'bg_id': '021700012022',
#                       'cerberus_id': 'd34b4788867bc5c8',
#                       'city': 'Palmer',
#                       'comp': 79,
#                       'construction_type': 'Frame ,Wood Siding',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 492808,
#                       'days_on_market': 31.0,
#                       'distance_miles': 1.8963936645503034,
#                       'flips': None,
#                       'garage_num_cars': 3,
#                       'garage_type': 'Garage Door Opener,Paved,Attached,Heated '
#                                      'Garage,No Carport',
#                       'geo_location': {'latitude': 61.5889435,
#                                        'longitude': -149.1387482},
#                       'gross_living_area_sqft': 2255,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 492808,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-01',
#                       'last_list_price': 519000,
#                       'last_list_price_adjusted': 348016,
#                       'listing_entity_id': '65bd46c23957fc0833b5ca12',
# ...
#                            'county_fips': '02170',
#                            'cumulative_days_on_market': None,
#                            'current_value': 343449,
#                            'days_on_market': 3.0,
#                            'distance_miles': 2.7184798906074037,
#                            'flips': None,
#                            'garage_num_cars': 2,
#                            'garage_type': 'Detached,Other,See Remarks',
#                            'geo_location': {'latitude': 61.59507,
#                                             'longitude': -149.03665},
#                            'gross_living_area_sqft': 1568,
#                            'hc_mls_id': 2,
#                            'housecanary_value': 343449,
#                            'is_distressed': False,
#                            'is_in_non_disclosure_state': True,
#                            'last_list_date': '2023-03-01',
#                            'last_list_price': 316000,
#                            'last_list_price_adjusted': 352400,
#                            'listing_entity_id': '6402e1651eb6712a68ed0d17',
#                            'listing_id': '23-1946',
#                            'listing_status': 'Sold',
#                            'listing_status_date': '2023-05-02',
#                            'net_dollar_adjustment': 8951.51,
#                            'pool': False,
#                            'property_status': 'Sold',
#                            'property_type': 'Single Family Detached',
#                            'sales_date': '2023-05-02',
#                            'sales_price': None,
#                            'similarity_level': 'moderate',
#                            'similarity_level_adjusted': 'moderate',
#                            'similarity_score': 78,
#                            'similarity_score_adjusted': 76,
#                            'site_area_sqft': 86684,
#                            'source_id': 1,
#                            'state': 'AK',
#                            'stories': None,
#                            'street_address': '1405 N Kuhn Dr',
#                            'subdivision_name': '',
#                            'tab_block_id': '021700013003009',
#                            'tract_id': '02170001300',
#                            'unit': None,
#                            'unit_designator': None,
#                            'year_built': 1978,
#                            'zipcode': '99645'},
#                           {'active_days_on_market': None,
#                            'address_id': 5520626,
#                            'address_slug': '5300-E-Aspen-St-Wasilla-AK-99654',
#                            'age': 42,
#                            'apn': '6445B09L005',
#                            'basement': None,
#                            'bathrooms': 1.0,
#                            'bedrooms': 3,
#                            'bg_id': '021700010032',
#                            'cerberus_id': '2e1c20efba0dd753',
#                            'city': 'Wasilla',
#                            'comp': 10,
#                            'construction_type': 'Frame ,Wood Siding',
#                            'county_fips': '02170',
#                            'cumulative_days_on_market': None,
#                            'current_value': 343368,
#                            'days_on_market': 5.0,
#                            'distance_miles': 6.785170879548294,
#                            'flips': None,
#                            'garage_num_cars': 2,
#                            'garage_type': 'RV Access/Parking,Detached',
#                            'geo_location': {'latitude': 61.61022,
#                                             'longitude': -149.3170901},
#                            'gross_living_area_sqft': 1120,
#                            'hc_mls_id': 2,
#                            'housecanary_value': 343368,
#                            'is_distressed': False,
#                            'is_in_non_disclosure_state': True,
#                            'last_list_date': '2023-02-22',
#                            'last_list_price': 325000,
#                            'last_list_price_adjusted': 382523,
#                            'listing_entity_id': '63fc7843f607946f25d23dec',
#                            'listing_id': '23-1572',
#                            'listing_status': 'Sold',
#                            'listing_status_date': '2023-04-28',
#                            'net_dollar_adjustment': 39155.91,
#                            'pool': False,
#                            'property_status': 'Sold',
#                            'property_type': 'Single Family Detached',
#                            'sales_date': '2023-04-28',
#                            'sales_price': None,
#                            'similarity_level': 'moderate',
#                            'similarity_level_adjusted': 'moderate',
#                            'similarity_score': 84,
#                            'similarity_score_adjusted': 76,
#                            'site_area_sqft': 32616,
#                            'source_id': 1,
#                            'state': 'AK',
#                            'stories': None,
#                            'street_address': '5300 E Aspen St',
#                            'subdivision_name': '',
#                            'tab_block_id': '021700010032010',
#                            'tract_id': '02170001003',
#                            'unit': None,
#                            'unit_designator': None,
#                            'year_built': 1982,
#                            'zipcode': '99654'},
#                           {'active_days_on_market': None,
#                            'address_id': 50506849,
#                            'address_slug': '1227-N-Angus-Loop-Palmer-AK-99645',
#                            'age': 11,
#                            'apn': '6974B11L007',
#                            'basement': False,
#                            'bathrooms': 2.0,
#                            'bedrooms': 2,
#                            'bg_id': '021700012013',
#                            'cerberus_id': '3a5eed07a630775c',
#                            'city': 'Palmer',
#                            'comp': 11,
#                            'construction_type': 'Frame ,Wood Siding',
#                            'county_fips': '02170',
#                            'cumulative_days_on_market': None,
#                            'current_value': 332639,
#                            'days_on_market': 4.0,
#                            'distance_miles': 2.189400319917611,
#                            'flips': None,
#                            'garage_num_cars': 2,
#                            'garage_type': 'Garage Door Opener,Attached,Heated '
#                                           'Garage',
#                            'geo_location': {'latitude': 61.5812874,
#                                             'longitude': -149.1050569},
#                            'gross_living_area_sqft': 1214,
#                            'hc_mls_id': 2,
#                            'housecanary_value': 332639,
#                            'is_distressed': False,
#                            'is_in_non_disclosure_state': True,
#                            'last_list_date': '2023-02-24',
#                            'last_list_price': 299000,
#                            'last_list_price_adjusted': 281225,
#                            'listing_entity_id': '63f92bcca921c05d2a971cd0',
#                            'listing_id': '23-1641',
#                            'listing_status': 'Sold',
#                            'listing_status_date': '2023-04-25',
#                            'net_dollar_adjustment': -51413.83,
#                            'pool': False,
#                            'property_status': 'Sold',
#                            'property_type': 'Single Family Detached',
#                            'sales_date': '2023-04-25',
#                            'sales_price': None,
#                            'similarity_level': 'moderate',
#                            'similarity_level_adjusted': 'moderate',
#                            'similarity_score': 78,
#                            'similarity_score_adjusted': 76,
#                            'site_area_sqft': 20038,
#                            'source_id': 1,
#                            'state': 'AK',
#                            'stories': None,
#                            'street_address': '1227 N Angus Loop',
#                            'subdivision_name': '',
#                            'tab_block_id': '021700012013021',
#                            'tract_id': '02170001201',
#                            'unit': None,
#                            'unit_designator': None,
#                            'year_built': 2013,
#                            'zipcode': '99645'},
#                           {'active_days_on_market': None,
#                            'address_id': 83417115,
#                            'address_slug': '15860-E-Clark-Wolverine-Rd-Palmer-AK-99645',
#                            'age': 54,
#                            'apn': '3019000L010-1',
#                            'basement': None,
#                            'bathrooms': 1.0,
#                            'bedrooms': 2,
#                            'bg_id': '021700013004',
#                            'cerberus_id': 'd97e27fdb867b335',
#                            'city': 'Palmer',
#                            'comp': 12,
#                            'construction_type': 'Log ,Log Siding',
#                            'county_fips': '02170',
#                            'cumulative_days_on_market': None,
#                            'current_value': 255473,
#                            'days_on_market': 4.0,
#                            'distance_miles': 1.9590452074139373,
#                            'flips': None,
#                            'garage_num_cars': 2,
#                            'garage_type': 'Detached,No Carport',
#                            'geo_location': {'latitude': 61.613456,
#                                             'longitude': -149.0508051},
#                            'gross_living_area_sqft': 1130,
#                            'hc_mls_id': 2,
#                            'housecanary_value': 255473,
#                            'is_distressed': False,
#                            'is_in_non_disclosure_state': True,
#                            'last_list_date': '2024-02-02',
#                            'last_list_price': 250000,
#                            'last_list_price_adjusted': 273254,
#                            'listing_entity_id': '65c1c7d897054c019e90fcc0',
#                            'listing_id': '24-1078',
#                            'listing_status': 'Pending',
#                            'listing_status_date': '2024-02-05',
#                            'net_dollar_adjustment': 23254.7,
#                            'pool': None,
#                            'property_status': 'Pending',
#                            'property_type': 'Single Family Detached',
#                            'sales_date': '',
#                            'sales_price': None,
#                            'similarity_level': 'low',
#                            'similarity_level_adjusted': 'moderate',
#                            'similarity_score': 76,
#                            'similarity_score_adjusted': 75,
#                            'site_area_sqft': 67518,
#                            'source_id': 1,
#                            'state': 'AK',
#                            'stories': None,
#                            'street_address': '15860 E Clark Wolverine Rd',
#                            'subdivision_name': '',
#                            'tab_block_id': '021700013004010',
#                            'tract_id': '02170001300',
#                            'unit': None,
#                            'unit_designator': None,
#                            'year_built': 1970,
#                            'zipcode': '99645'}],
#  'rental_comp_avm': {'fsd': None,
#                      'valuation_suitability_score': None,
#                      'valuation_suitability_score_desc': None},
#  'report_type': 'full',
#  'subject': {'active_days_on_market': None,
#              'address_id': 27076470,
#              'address_slug': '517-N-Chugach-St-Palmer-AK-99645',
#              'age': 42,
#              'apn': '5020B02L020',
#              'basement': False,
#              'bathrooms': 2,
#              'bedrooms': 3,
#              'bg_id': '021700012011',
#              'cerberus_id': '45c02709836063f0',
#              'city': 'Palmer',
#              'construction_type': 'Wood Siding',
#              'county_fips': '02170',
#              'county_name': 'Matanuska-Susitna Borough',
#              'cumulative_days_on_market': None,
#              'current_owner_mailing_city': 'Palmer',
#              'current_owner_mailing_state': 'AK',
#              'current_owner_mailing_street_address': '517 N Chugach St',
#              'current_owner_mailing_zipcode': '99645',
#              'current_owner_mailing_zipcode4': '6039',
#              'current_value': 299803,
#              'days_on_market': 92,
#              'flips': None,
#              'garage_num_cars': 1,
#              'garage_type': 'Garage Door Opener,Attached,Heated Garage,No '
#                             'Carport',
#              'geo_location': {'latitude': 61.6128922,
#                               'longitude': -149.1104737},
#              'geo_precision': 'parcel',
#              'gross_living_area_sqft': 1410,
#              'hc_mls_id': 2,
#              'housecanary_value': 299803,
#              'is_distressed': True,
#              'is_in_non_disclosure_state': True,
#              'is_owner_occupied': True,
#              'last_list_date': '2020-04-23',
#              'last_list_price': 189900,
#              'listing_entity_id': '61e76c9d1358f21be9eb7983',
#              'listing_id': '20-5333',
#              'listing_status': 'Sold',
#              'listing_status_date': '2020-07-24',
#              'pool': False,
#              'property_status': 'Sold',
#              'property_type': 'Single Family Detached',
#              'quality': 'CON4',
#              'raw_land_use_code': None,
#              'rental_avm': {'fsd': 0.0939664,
#                             'price_lwr': 1833,
#                             'price_mean': 2022,
#                             'price_per_sqft_lwr': 1.3,
#                             'price_per_sqft_mean': 1.4340425531914893,
#                             'price_per_sqft_upr': 1.5695035460992908,
#                             'price_upr': 2213,
#                             'valuation_suitability_score': 91,
#                             'valuation_suitability_score_desc': 'high'},
#              'sales_date': '2017-09-07',
#              'sales_price': None,
#              'site_area_sqft': 10454,
#              'source_id': 1,
#              'state': 'AK',
#              'stories': None,
#              'street_address': '517 N Chugach St',
#              'subdivision_name': 'Riverside',
#              'tab_block_id': '021700012011002',
#              'tract_id': '02170001201',
#              'unit': None,
#              'unit_designator': None,
#              'year_built': 1982,
#              'zipcode': '99645',
#              'zipcode4': '6039'},
#  'subject_listing_history': [{'event': 'Listed',
#                               'list_date': '2020-04-23',
#                               'list_price': 189900,
#                               'source': 'MLS',
#                               'source_id': 1},
#                              {'event': 'Listed',
#                               'list_date': '2017-05-25',
#                               'list_price': 190000,
#                               'source': 'MLS',
#                               'source_id': 1}],
#  'subject_purchase_history': [{'sales_date': '2017-09-07',
#                                'sales_price': None,
#                                'source': 'MLS'},
#                               {'sales_date': '2005-11-10',
#                                'sales_price': None,
#                                'source': 'Public Records'}],
#  'version': '1'}

# %%
# Finally, let's try the Rental Report API.

url = 'https://api.housecanary.com/v2/property/rental_report'

params = {'address': sample_address['address'],
          'zipcode': sample_address['zipcode'],
          'format': 'json'}

response = requests.get(url, params=params, auth=(test_key, test_secret))

print(response.url)
pprint.pprint(response.json())

# use response.json() to get the Rental Report json. The content is too long to display here.
# Out:
# https://api.housecanary.com/v2/property/rental_report?address=517+N+Chugach+St&zipcode=99645&format=json
# {'active_listings': [{'active_days_on_market': None,
#                       'address_id': 311013903,
#                       'address_slug': '1735-N-Fanciful-Pl-Unit-A-Wasilla-AK-99654',
#                       'age': None,
#                       'apn': '',
#                       'basement': None,
#                       'bathrooms': 1.5,
#                       'bedrooms': 2,
#                       'bg_id': '021700008002',
#                       'cerberus_id': '3c09f0dc72a6e640',
#                       'city': 'Wasilla',
#                       'comp': 9,
#                       'construction_type': 'Unknown',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 247491,
#                       'days_on_market': 31,
#                       'distance_miles': 11.754431225625051,
#                       'flips': None,
#                       'garage_num_cars': None,
#                       'garage_type': 'Unknown',
#                       'geo_location': {'latitude': 61.5989227,
#                                        'longitude': -149.46727},
#                       'gross_living_area_sqft': 1200,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 247491,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-24',
#                       'last_list_price': 1695,
#                       'last_list_price_adjusted': 30634,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '65b16cb9008d8e13281e3d9a',
#                       'listing_id': '24-753',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-24',
#                       'net_dollar_adjustment': 28939.13,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0899896,
#                                      'price_lwr': 1755,
#                                      'price_mean': 1928,
#                                      'price_per_sqft_lwr': 1.4625,
#                                      'price_per_sqft_mean': 1.6066666666666667,
#                                      'price_per_sqft_upr': 1.7516666666666667,
#                                      'price_upr': 2102,
#                                      'valuation_suitability_score': 91,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'high',
#                       'similarity_level_adjusted': 'moderate',
#                       'similarity_score': 89,
#                       'similarity_score_adjusted': 80,
#                       'site_area_sqft': 40075,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '1735 N Fanciful Pl',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700008002001',
#                       'tract_id': '02170000800',
#                       'unit': 'Unit A',
#                       'unit_designator': None,
#                       'year_built': None,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 321586427,
#                       'address_slug': '6080-E-Gershmel-Loop-Unit-4-Palmer-AK-99645',
#                       'age': None,
#                       'apn': '',
#                       'basement': None,
#                       'bathrooms': 1.5,
#                       'bedrooms': 2,
#                       'bg_id': '021700011001',
#                       'cerberus_id': '764deb471eab6279',
#                       'city': 'Palmer',
#                       'comp': 15,
#                       'construction_type': 'Unknown',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 264950,
#                       'days_on_market': 60,
#                       'distance_miles': 7.115720074868861,
#                       'flips': None,
#                       'garage_num_cars': None,
#                       'garage_type': 'Unknown',
#                       'geo_location': {'latitude': 61.560516,
#                                        'longitude': -149.297006},
#                       'gross_living_area_sqft': 1050,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 264950,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-04',
#                       'last_list_price': 1475,
#                       'last_list_price_adjusted': 52285,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '65970ec43444a6142e994ed0',
#                       'listing_id': '24-112',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-04',
#                       'net_dollar_adjustment': 50810.64,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0206897,
#                                      'price_lwr': 1420,
#                                      'price_mean': 1450,
#                                      'price_per_sqft_lwr': 1.3523809523809525,
#                                      'price_per_sqft_mean': 1.380952380952381,
#                                      'price_per_sqft_upr': 1.4095238095238096,
#                                      'price_upr': 1480,
#                                      'valuation_suitability_score': 98,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'moderate',
#                       'similarity_level_adjusted': 'moderate',
#                       'similarity_score': 83,
#                       'similarity_score_adjusted': 78,
#                       'site_area_sqft': None,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '6080 E Gershmel Loop',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700011001033',
#                       'tract_id': '02170001100',
#                       'unit': 'Unit 4',
#                       'unit_designator': None,
#                       'year_built': None,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 48934800,
#                       'address_slug': '3800-N-Engstrom-Rd-Wasilla-AK-99654',
#                       'age': 25,
#                       'apn': '1344B07L030',
#                       'basement': None,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700010012',
#                       'cerberus_id': 'ead489c4d3806c3e',
#                       'city': 'Wasilla',
#                       'comp': 22,
#                       'construction_type': 'Frame',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 587883,
#                       'days_on_market': 36,
#                       'distance_miles': 4.971144103442127,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Driveway,Attached,Garage Door '
#                                      'Opener,Heated Garage,Lighted,Paved',
#                       'geo_location': {'latitude': 61.62396,
#                                        'longitude': -149.2601401},
#                       'gross_living_area_sqft': 1320,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 587883,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-19',
#                       'last_list_price': 2500,
#                       'last_list_price_adjusted': 2500,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '65aaf8739a2df508b84600a4',
#                       'listing_id': '24-627',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-19',
#                       'net_dollar_adjustment': 0,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.033963,
#                                      'price_lwr': 2404,
#                                      'price_mean': 2488,
#                                      'price_per_sqft_lwr': 1.8212121212121213,
#                                      'price_per_sqft_mean': 1.8848484848484848,
#                                      'price_per_sqft_upr': 1.9492424242424242,
#                                      'price_upr': 2573,
#                                      'valuation_suitability_score': 97,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '2022-02-25',
#                       'sales_price': None,
#                       'similarity_level': 'moderate',
#                       'similarity_level_adjusted': 'moderate',
#                       'similarity_score': 79,
#                       'similarity_score_adjusted': 76,
#                       'site_area_sqft': 43124,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '3800 N Engstrom Rd',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700010012015',
#                       'tract_id': '02170001001',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 1999,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 321586429,
#                       'address_slug': '6080-E-Gershmel-Loop-Unit-3-Palmer-AK-99645',
#                       'age': None,
#                       'apn': '',
#                       'basement': None,
#                       'bathrooms': 1.5,
#                       'bedrooms': 2,
#                       'bg_id': '021700011001',
#                       'cerberus_id': '53d791f1247ab967',
#                       'city': 'Palmer',
#                       'comp': 43,
#                       'construction_type': 'Unknown',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 280192,
#                       'days_on_market': 60,
#                       'distance_miles': 7.173261670876924,
#                       'flips': None,
#                       'garage_num_cars': None,
#                       'garage_type': 'Unknown',
#                       'geo_location': {'latitude': 61.560315,
#                                        'longitude': -149.298789},
#                       'gross_living_area_sqft': 1050,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 280192,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-04',
#                       'last_list_price': 1475,
#                       'last_list_price_adjusted': 1475,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '65970ec43444a6142e994ece',
#                       'listing_id': '24-111',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-04',
#                       'net_dollar_adjustment': 0,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0251551,
#                                      'price_lwr': 1415,
#                                      'price_mean': 1451,
#                                      'price_per_sqft_lwr': 1.3476190476190477,
#                                      'price_per_sqft_mean': 1.381904761904762,
#                                      'price_per_sqft_upr': 1.417142857142857,
#                                      'price_upr': 1488,
#                                      'valuation_suitability_score': 97,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 76,
#                       'similarity_score_adjusted': 71,
#                       'site_area_sqft': None,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '6080 E Gershmel Loop',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700011001031',
#                       'tract_id': '02170001100',
#                       'unit': 'Unit 3',
#                       'unit_designator': None,
#                       'year_built': None,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 298511353,
#                       'address_slug': '2270-W-Ridgewood-Dr-Unit-2-Wasilla-AK-99654',
#                       'age': 10,
#                       'apn': '',
#                       'basement': None,
#                       'bathrooms': 2.5,
#                       'bedrooms': 3,
#                       'bg_id': '021700007052',
#                       'cerberus_id': '9651818201794d14',
#                       'city': 'Wasilla',
#                       'comp': 71,
#                       'construction_type': 'Frame',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 348944,
#                       'days_on_market': 69,
#                       'distance_miles': 12.981642926243893,
#                       'flips': None,
#                       'garage_num_cars': 1,
#                       'garage_type': 'Attached',
#                       'geo_location': {'latitude': 61.6018295,
#                                        'longitude': -149.505188},
#                       'gross_living_area_sqft': 1313,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 348944,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2023-12-18',
#                       'last_list_price': 2095,
#                       'last_list_price_adjusted': 2095,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '658124af800c0001bd1dc3cd',
#                       'listing_id': '23-14365',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2023-12-18',
#                       'net_dollar_adjustment': 0,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.02019,
#                                      'price_lwr': 2063,
#                                      'price_mean': 2105,
#                                      'price_per_sqft_lwr': 1.5712109672505712,
#                                      'price_per_sqft_mean': 1.603198781416603,
#                                      'price_per_sqft_upr': 1.635948210205636,
#                                      'price_upr': 2148,
#                                      'valuation_suitability_score': 98,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 76,
#                       'similarity_score_adjusted': 66,
#                       'site_area_sqft': 48351,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '2270 W Ridgewood Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700007052013',
#                       'tract_id': '02170000705',
#                       'unit': 'Unit 2',
#                       'unit_designator': None,
#                       'year_built': 2014,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 298507499,
#                       'address_slug': '2270-W-Ridgewood-Dr-Unit-4-Wasilla-AK-99654',
#                       'age': 10,
#                       'apn': '',
#                       'basement': None,
#                       'bathrooms': 2.5,
#                       'bedrooms': 3,
#                       'bg_id': '021700007052',
#                       'cerberus_id': '0afba18d98a55431',
#                       'city': 'Wasilla',
#                       'comp': 73,
#                       'construction_type': 'Frame',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 348635,
#                       'days_on_market': 96,
#                       'distance_miles': 12.981642926243893,
#                       'flips': None,
#                       'garage_num_cars': 1,
#                       'garage_type': 'Attached',
#                       'geo_location': {'latitude': 61.6018295,
#                                        'longitude': -149.505188},
#                       'gross_living_area_sqft': 1313,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 348635,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2023-11-21',
#                       'last_list_price': 2095,
#                       'last_list_price_adjusted': 276966,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '655d8b55b1af6904999e8853',
#                       'listing_id': '23-13744',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2023-11-21',
#                       'net_dollar_adjustment': -71668.79,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0199241,
#                                      'price_lwr': 2067,
#                                      'price_mean': 2108,
#                                      'price_per_sqft_lwr': 1.5742574257425743,
#                                      'price_per_sqft_mean': 1.6054836252856055,
#                                      'price_per_sqft_upr': 1.6382330540746382,
#                                      'price_upr': 2151,
#                                      'valuation_suitability_score': 98,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 76,
#                       'similarity_score_adjusted': 66,
#                       'site_area_sqft': 48351,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '2270 W Ridgewood Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700007052013',
#                       'tract_id': '02170000705',
#                       'unit': 'Unit 4',
#                       'unit_designator': None,
#                       'year_built': 2014,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 312948924,
#                       'address_slug': '1650-N-Winding-Brook-Loop-Unit-House-Palmer-AK-99645',
#                       'age': 14,
#                       'apn': '',
#                       'basement': None,
#                       'bathrooms': 1.0,
#                       'bedrooms': 2,
#                       'bg_id': '021700010042',
#                       'cerberus_id': '657bfd86018bb7d7',
#                       'city': 'Palmer',
#                       'comp': 78,
#                       'construction_type': 'Unknown',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': None,
#                       'days_on_market': 32,
#                       'distance_miles': 4.784458536870266,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Covered, Garage',
#                       'geo_location': {'latitude': 61.5979805,
#                                        'longitude': -149.2527772},
#                       'gross_living_area_sqft': 1000,
#                       'hc_mls_id': 2,
#                       'housecanary_value': None,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-02',
#                       'last_list_price': 1695,
#                       'last_list_price_adjusted': 1695,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '65bdcc588a43e00a2f53eb6e',
#                       'listing_id': '24-1076',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-02',
#                       'net_dollar_adjustment': 0,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 67,
#                       'similarity_score_adjusted': 65,
#                       'site_area_sqft': 124581,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '1650 N Winding Brook Loop',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700010042000',
#                       'tract_id': '02170001004',
#                       'unit': 'Unit House',
#                       'unit_designator': None,
#                       'year_built': 2010,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 2216333,
#                       'address_slug': '9040-E-Gold-Pan-Dr-Palmer-AK-99645',
#                       'age': 15,
#                       'apn': '1416B04L002',
#                       'basement': None,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700011002',
#                       'cerberus_id': 'a6b9b600406fa7be',
#                       'city': 'Palmer',
#                       'comp': 88,
#                       'construction_type': 'Frame',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 416711,
#                       'days_on_market': 91,
#                       'distance_miles': 3.914951207805201,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Driveway,Attached,Garage Door '
#                                      'Opener,Heated '
#                                      'Garage,Gravel,Guest,Parking Lot,RV '
#                                      'Access/Parking',
#                       'geo_location': {'latitude': 61.59296,
#                                        'longitude': -149.22209},
#                       'gross_living_area_sqft': 1550,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 416711,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2023-12-01',
#                       'last_list_price': 2100,
#                       'last_list_price_adjusted': 2100,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '6590cba659a50c11e0c25ffa',
#                       'listing_id': '23-14558',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2023-12-30',
#                       'net_dollar_adjustment': 0,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0250238,
#                                      'price_lwr': 2046,
#                                      'price_mean': 2098,
#                                      'price_per_sqft_lwr': 1.32,
#                                      'price_per_sqft_mean': 1.3535483870967742,
#                                      'price_per_sqft_upr': 1.387741935483871,
#                                      'price_upr': 2151,
#                                      'valuation_suitability_score': 97,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '2011-03-22',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 65,
#                       'similarity_score_adjusted': 63,
#                       'site_area_sqft': 85377,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '9040 E Gold Pan Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700011002017',
#                       'tract_id': '02170001100',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2009,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 313419146,
#                       'address_slug': '1650-N-Winding-Brook-Loop-Unit-B-Palmer-AK-99645',
#                       'age': 52,
#                       'apn': '',
#                       'basement': None,
#                       'bathrooms': 1.0,
#                       'bedrooms': 2,
#                       'bg_id': '021700010042',
#                       'cerberus_id': 'e34e43861feda894',
#                       'city': 'Palmer',
#                       'comp': 94,
#                       'construction_type': 'Unknown',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 265406,
#                       'days_on_market': 46,
#                       'distance_miles': 4.784458536870266,
#                       'flips': None,
#                       'garage_num_cars': None,
#                       'garage_type': 'Unknown',
#                       'geo_location': {'latitude': 61.5979805,
#                                        'longitude': -149.2527772},
#                       'gross_living_area_sqft': 575,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 265406,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-17',
#                       'last_list_price': 1250,
#                       'last_list_price_adjusted': 81131,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '65a8c26523402601737c59c7',
#                       'listing_id': '24-545',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-17',
#                       'net_dollar_adjustment': 79881.31,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0201288,
#                                      'price_lwr': 1218,
#                                      'price_mean': 1242,
#                                      'price_per_sqft_lwr': 2.1182608695652174,
#                                      'price_per_sqft_mean': 2.16,
#                                      'price_per_sqft_upr': 2.205217391304348,
#                                      'price_upr': 1268,
#                                      'valuation_suitability_score': 98,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 63,
#                       'similarity_score_adjusted': 61,
#                       'site_area_sqft': 124581,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '1650 N Winding Brook Loop',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700010042000',
#                       'tract_id': '02170001004',
#                       'unit': 'Unit B',
#                       'unit_designator': None,
#                       'year_built': 1972,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 298565605,
#                       'address_slug': '4100-N-Patrick-Cir-Apt-3-Wasilla-AK-99654',
#                       'age': 11,
#                       'apn': '',
#                       'basement': None,
#                       'bathrooms': 2.5,
#                       'bedrooms': 3,
#                       'bg_id': '021700010011',
#                       'cerberus_id': '34f5b7b4dae0947d',
#                       'city': 'Wasilla',
#                       'comp': 144,
#                       'construction_type': 'Concrete ,Frame',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 385476,
#                       'days_on_market': 50,
#                       'distance_miles': 8.841936187031108,
#                       'flips': None,
#                       'garage_num_cars': 1,
#                       'garage_type': 'Attached',
#                       'geo_location': {'latitude': 61.6279182,
#                                        'longitude': -149.3780366},
#                       'gross_living_area_sqft': 1336,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 385476,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-05',
#                       'last_list_price': 2095,
#                       'last_list_price_adjusted': 2095,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '6598ad9637450a5a0c7b6dbd',
#                       'listing_id': '24-174',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-05',
#                       'net_dollar_adjustment': 0,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0199423,
#                                      'price_lwr': 2040,
#                                      'price_mean': 2081,
#                                      'price_per_sqft_lwr': 1.526946107784431,
#                                      'price_per_sqft_mean': 1.5576347305389222,
#                                      'price_per_sqft_upr': 1.589071856287425,
#                                      'price_upr': 2123,
#                                      'valuation_suitability_score': 98,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 61,
#                       'similarity_score_adjusted': 54,
#                       'site_area_sqft': 43560,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '4100 N Patrick Cir',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700010011021',
#                       'tract_id': '02170001001',
#                       'unit': 'Apt 3',
#                       'unit_designator': None,
#                       'year_built': 2013,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 298502270,
#                       'address_slug': '8913-E-Windy-Woods-Loop-Palmer-AK-99645',
#                       'age': 3,
#                       'apn': '8051B03L007',
#                       'basement': None,
#                       'bathrooms': 3.0,
#                       'bedrooms': 4,
#                       'bg_id': '021700003002',
#                       'cerberus_id': '5962911d3dce25fb',
#                       'city': 'Palmer',
#                       'comp': 190,
#                       'construction_type': 'Frame',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 717984,
#                       'days_on_market': 40,
#                       'distance_miles': 5.7197021768461624,
#                       'flips': None,
#                       'garage_num_cars': 3,
#                       'garage_type': 'Driveway,Attached,Garage Door '
#                                      'Opener,Heated Garage,Paved',
#                       'geo_location': {'latitude': 61.6595802,
#                                        'longitude': -149.2545167},
#                       'gross_living_area_sqft': 2540,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 717984,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-20',
#                       'last_list_price': 3700,
#                       'last_list_price_adjusted': 3700,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '65ac6a76db79bc042d4bacbe',
#                       'listing_id': '24-658',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-20',
#                       'net_dollar_adjustment': 0,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0894879,
#                                      'price_lwr': 3378,
#                                      'price_mean': 3710,
#                                      'price_per_sqft_lwr': 1.3299212598425196,
#                                      'price_per_sqft_mean': 1.4606299212598426,
#                                      'price_per_sqft_upr': 1.5913385826771653,
#                                      'price_upr': 4042,
#                                      'valuation_suitability_score': 91,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '2022-01-05',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 47,
#                       'similarity_score_adjusted': 44,
#                       'site_area_sqft': 43124,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '8913 E Windy Woods Loop',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700003002005',
#                       'tract_id': '02170000300',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2021,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 317892393,
#                       'address_slug': '350-E-Palmer-Wasilla-Hwy-Unit-A6-Wasilla-AK-99654',
#                       'age': 49,
#                       'apn': '',
#                       'basement': None,
#                       'bathrooms': 1.0,
#                       'bedrooms': 2,
#                       'bg_id': '021700009002',
#                       'cerberus_id': '6248b82e4b719b8d',
#                       'city': 'Wasilla',
#                       'comp': 206,
#                       'construction_type': 'Frame',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 457085,
#                       'days_on_market': 1,
#                       'distance_miles': 11.151249146582458,
#                       'flips': None,
#                       'garage_num_cars': None,
#                       'garage_type': 'Unknown',
#                       'geo_location': {'latitude': 61.5687943,
#                                        'longitude': -149.4370422},
#                       'gross_living_area_sqft': 800,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 457085,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-23',
#                       'last_list_price': 1295,
#                       'last_list_price_adjusted': 1295,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '65d97bce47d61a0073685752',
#                       'listing_id': '24-1747',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-23',
#                       'net_dollar_adjustment': 0,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': '-',
#                       'rental_avm': {'fsd': 0.0407759,
#                                      'price_lwr': 1212,
#                                      'price_mean': 1263,
#                                      'price_per_sqft_lwr': 1.515,
#                                      'price_per_sqft_mean': 1.57875,
#                                      'price_per_sqft_upr': 1.64375,
#                                      'price_upr': 1315,
#                                      'valuation_suitability_score': 96,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 47,
#                       'similarity_score_adjusted': 38,
#                       'site_area_sqft': 107157,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '350 E Palmer Wasilla Hwy',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700009002028',
#                       'tract_id': '02170000900',
#                       'unit': 'Unit A6',
#                       'unit_designator': None,
#                       'year_built': 1975,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 305783408,
#                       'address_slug': '340-E-Palmer-Wasilla-Hwy-Unit-B5-Wasilla-AK-99654',
#                       'age': 49,
#                       'apn': '57869000L001',
#                       'basement': None,
#                       'bathrooms': 1.0,
#                       'bedrooms': 2,
#                       'bg_id': '021700009002',
#                       'cerberus_id': 'd0573c67c50aa0f5',
#                       'city': 'Wasilla',
#                       'comp': 207,
#                       'construction_type': 'Frame',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 456537,
#                       'days_on_market': 26,
#                       'distance_miles': 11.296434730892859,
#                       'flips': None,
#                       'garage_num_cars': None,
#                       'garage_type': 'Unknown',
#                       'geo_location': {'latitude': 61.5691833,
#                                        'longitude': -149.441864},
#                       'gross_living_area_sqft': 800,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 456537,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-29',
#                       'last_list_price': 1295,
#                       'last_list_price_adjusted': 1295,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '65b86a3e5ec5cb0bb227e324',
#                       'listing_id': '24-925',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-01-29',
#                       'net_dollar_adjustment': 0,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0428232,
#                                      'price_lwr': 1207,
#                                      'price_mean': 1261,
#                                      'price_per_sqft_lwr': 1.50875,
#                                      'price_per_sqft_mean': 1.57625,
#                                      'price_per_sqft_upr': 1.64375,
#                                      'price_upr': 1315,
#                                      'valuation_suitability_score': 96,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 47,
#                       'similarity_score_adjusted': 38,
#                       'site_area_sqft': 107157,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '340 E Palmer Wasilla Hwy',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700009002028',
#                       'tract_id': '02170000900',
#                       'unit': 'Unit B5',
#                       'unit_designator': None,
#                       'year_built': 1975,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 25179478,
#                       'address_slug': '2115-N-Belmont-Ave-Palmer-AK-99645',
#                       'age': 39,
#                       'apn': '2946B02L004',
#                       'basement': None,
#                       'bathrooms': None,
#                       'bedrooms': 3,
#                       'bg_id': '021700012021',
#                       'cerberus_id': '2d4148c2fa5f5cea',
#                       'city': 'Palmer',
#                       'comp': 223,
#                       'construction_type': 'Unknown',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 383249,
#                       'days_on_market': 14,
#                       'distance_miles': 1.88595819765141,
#                       'flips': None,
#                       'garage_num_cars': None,
#                       'garage_type': 'Attached',
#                       'geo_location': {'latitude': 61.6033211,
#                                        'longitude': -149.1642762},
#                       'gross_living_area_sqft': 2,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 383249,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-02-14',
#                       'last_list_price': 2600,
#                       'last_list_price_adjusted': 230467,
#                       'leased_date': '',
#                       'leased_price': None,
#                       'listing_entity_id': '65cee6bf40c8c1003fa15754',
#                       'listing_id': '24-1389',
#                       'listing_status': 'Active',
#                       'listing_status_date': '2024-02-14',
#                       'net_dollar_adjustment': 227867.07,
#                       'pool': None,
#                       'property_status': 'Active',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0694505,
#                                      'price_lwr': 2151,
#                                      'price_mean': 2311,
#                                      'price_per_sqft_lwr': 1075.5,
#                                      'price_per_sqft_mean': 1155.5,
#                                      'price_per_sqft_upr': 1236.0,
#                                      'price_upr': 2472,
#                                      'valuation_suitability_score': 93,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '2021-03-19',
#                       'sales_price': None,
#                       'similarity_level': 'low',
# ...
#                       'gross_living_area_sqft': 1300,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 214703,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2024-01-26',
#                       'last_list_price': 1850,
#                       'last_list_price_adjusted': 1850,
#                       'leased_date': '2024-02-09',
#                       'leased_price': None,
#                       'listing_entity_id': '65b40c3d4e1829044eaa2d0b',
#                       'listing_id': '24-823',
#                       'listing_status': 'Sold',
#                       'listing_status_date': '2024-02-09',
#                       'net_dollar_adjustment': 0,
#                       'pool': None,
#                       'property_status': 'Leased',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0887691,
#                                      'price_lwr': 1607,
#                                      'price_mean': 1763,
#                                      'price_per_sqft_lwr': 1.2361538461538462,
#                                      'price_per_sqft_mean': 1.356153846153846,
#                                      'price_per_sqft_upr': 1.476923076923077,
#                                      'price_upr': 1920,
#                                      'valuation_suitability_score': 91,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '2021-10-01',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 0,
#                       'similarity_score_adjusted': 0,
#                       'site_area_sqft': 435,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '951 E Sue Ln',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700006011058',
#                       'tract_id': '02170000601',
#                       'unit': 'Unit 5C',
#                       'unit_designator': None,
#                       'year_built': 2005,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 46406679,
#                       'address_slug': '951-E-Sue-Ln-Unit-5A-Wasilla-AK-99654',
#                       'age': 19,
#                       'apn': '9045000U005-A',
#                       'basement': None,
#                       'bathrooms': 2.0,
#                       'bedrooms': 2,
#                       'bg_id': '021700006011',
#                       'cerberus_id': '7541e41847124c83',
#                       'city': 'Wasilla',
#                       'comp': 265,
#                       'construction_type': 'Frame',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 200066,
#                       'days_on_market': 16,
#                       'distance_miles': 11.030553143990517,
#                       'flips': None,
#                       'garage_num_cars': 1,
#                       'garage_type': 'Driveway,Attached,Garage Door '
#                                      'Opener,Paved',
#                       'geo_location': {'latitude': 61.5560074,
#                                        'longitude': -149.4241944},
#                       'gross_living_area_sqft': 1000,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 200066,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2023-11-29',
#                       'last_list_price': 1695,
#                       'last_list_price_adjusted': 1695,
#                       'leased_date': '2023-12-15',
#                       'leased_price': None,
#                       'listing_entity_id': '6567bf6dc3da0f030669ab43',
#                       'listing_id': '23-13892',
#                       'listing_status': 'Sold',
#                       'listing_status_date': '2023-12-15',
#                       'net_dollar_adjustment': 0,
#                       'pool': False,
#                       'property_status': 'Leased',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0199648,
#                                      'price_lwr': 1670,
#                                      'price_mean': 1703,
#                                      'price_per_sqft_lwr': 1.67,
#                                      'price_per_sqft_mean': 1.703,
#                                      'price_per_sqft_upr': 1.738,
#                                      'price_upr': 1738,
#                                      'valuation_suitability_score': 98,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '2018-08-06',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 0,
#                       'similarity_score_adjusted': 0,
#                       'site_area_sqft': 435,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '951 E Sue Ln',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700006011058',
#                       'tract_id': '02170000601',
#                       'unit': 'Unit 5A',
#                       'unit_designator': None,
#                       'year_built': 2005,
#                       'zipcode': '99654'},
#                      {'active_days_on_market': None,
#                       'address_id': 25490962,
#                       'address_slug': '2321-N-Broadway-Dr-Palmer-AK-99645',
#                       'age': 9,
#                       'apn': '2968B09L004',
#                       'basement': None,
#                       'bathrooms': None,
#                       'bedrooms': None,
#                       'bg_id': '021700011002',
#                       'cerberus_id': 'c875d4a1f82d181e',
#                       'city': 'Palmer',
#                       'comp': 266,
#                       'construction_type': 'Unknown',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 389044,
#                       'days_on_market': 27,
#                       'distance_miles': 3.5162309380789107,
#                       'flips': None,
#                       'garage_num_cars': None,
#                       'garage_type': 'Garage',
#                       'geo_location': {'latitude': 61.60585,
#                                        'longitude': -149.2165501},
#                       'gross_living_area_sqft': 2242,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 389044,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2023-08-30',
#                       'last_list_price': 2500,
#                       'last_list_price_adjusted': 389044,
#                       'leased_date': '2023-09-26',
#                       'leased_price': None,
#                       'listing_entity_id': '64f0293d4215820d3c1ea2a8',
#                       'listing_id': '23-10799',
#                       'listing_status': 'Sold',
#                       'listing_status_date': '2023-09-26',
#                       'net_dollar_adjustment': 0,
#                       'pool': False,
#                       'property_status': 'Leased',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0327545,
#                                      'price_lwr': 2452,
#                                      'price_mean': 2534,
#                                      'price_per_sqft_lwr': 1.0936663693131132,
#                                      'price_per_sqft_mean': 1.1302408563782338,
#                                      'price_per_sqft_upr': 1.167707404103479,
#                                      'price_upr': 2618,
#                                      'valuation_suitability_score': 97,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '2015-12-18',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 0,
#                       'similarity_score_adjusted': 0,
#                       'site_area_sqft': 20037,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '2321 N Broadway Dr',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700011002004',
#                       'tract_id': '02170001100',
#                       'unit': None,
#                       'unit_designator': None,
#                       'year_built': 2015,
#                       'zipcode': '99645'},
#                      {'active_days_on_market': None,
#                       'address_id': 151313721,
#                       'address_slug': '401-S-Wasilla-St-Unit-31-Wasilla-AK-99654',
#                       'age': 19,
#                       'apn': '9044000U031',
#                       'basement': True,
#                       'bathrooms': 2.0,
#                       'bedrooms': 3,
#                       'bg_id': '021700009002',
#                       'cerberus_id': 'fc55508aa8a2d69a',
#                       'city': 'Wasilla',
#                       'comp': 267,
#                       'construction_type': 'Frame',
#                       'county_fips': '02170',
#                       'cumulative_days_on_market': None,
#                       'current_value': 226684,
#                       'days_on_market': 56,
#                       'distance_miles': 10.662814300903548,
#                       'flips': None,
#                       'garage_num_cars': 2,
#                       'garage_type': 'Garage Door Opener,Paved,Attached,Tuck '
#                                      'Under',
#                       'geo_location': {'latitude': 61.5794601,
#                                        'longitude': -149.4274292},
#                       'gross_living_area_sqft': 1450,
#                       'hc_mls_id': 2,
#                       'housecanary_value': 226684,
#                       'is_distressed': False,
#                       'is_in_non_disclosure_state': True,
#                       'last_list_date': '2022-11-23',
#                       'last_list_price': 1725,
#                       'last_list_price_adjusted': 226684,
#                       'leased_date': '2023-01-18',
#                       'leased_price': None,
#                       'listing_entity_id': '637eac6a1c5c111105d9e198',
#                       'listing_id': '22-15341',
#                       'listing_status': 'Sold',
#                       'listing_status_date': '2023-01-18',
#                       'net_dollar_adjustment': 0,
#                       'pool': False,
#                       'property_status': 'Leased',
#                       'property_type': 'Single Family Detached',
#                       'rental_avm': {'fsd': 0.0603668,
#                                      'price_lwr': 1845,
#                                      'price_mean': 1963,
#                                      'price_per_sqft_lwr': 1.2724137931034483,
#                                      'price_per_sqft_mean': 1.353793103448276,
#                                      'price_per_sqft_upr': 1.4358620689655173,
#                                      'price_upr': 2082,
#                                      'valuation_suitability_score': 94,
#                                      'valuation_suitability_score_desc': 'high'},
#                       'sales_date': '2010-03-12',
#                       'sales_price': None,
#                       'similarity_level': 'low',
#                       'similarity_level_adjusted': 'low',
#                       'similarity_score': 0,
#                       'similarity_score_adjusted': 0,
#                       'site_area_sqft': 435,
#                       'source_id': 1,
#                       'state': 'AK',
#                       'stories': None,
#                       'street_address': '401 S Wasilla St',
#                       'subdivision_name': '',
#                       'tab_block_id': '021700009002021',
#                       'tract_id': '02170000900',
#                       'unit': 'Unit 31',
#                       'unit_designator': None,
#                       'year_built': 2005,
#                       'zipcode': '99654'}],
#  'effective_date': '2024-02-24',
#  'product_type': 'rental',
#  'report_type': 'full',
#  'subject': {'active_days_on_market': None,
#              'address_id': 27076470,
#              'address_slug': '517-N-Chugach-St-Palmer-AK-99645',
#              'age': 42,
#              'apn': '5020B02L020',
#              'basement': False,
#              'bathrooms': 2,
#              'bedrooms': 3,
#              'bg_id': '021700012011',
#              'cerberus_id': '',
#              'city': 'Palmer',
#              'construction_type': 'Wood Siding',
#              'county_fips': '02170',
#              'county_name': 'Matanuska-Susitna Borough',
#              'cumulative_days_on_market': None,
#              'current_owner_mailing_city': 'Palmer',
#              'current_owner_mailing_state': 'AK',
#              'current_owner_mailing_street_address': '517 N Chugach St',
#              'current_owner_mailing_zipcode': '99645',
#              'current_owner_mailing_zipcode4': '6039',
#              'current_value': 299803,
#              'flips': None,
#              'garage_num_cars': 1,
#              'garage_type': 'Garage Door Opener,Attached,Heated Garage,No '
#                             'Carport',
#              'geo_location': {'latitude': 61.6128922,
#                               'longitude': -149.1104737},
#              'geo_precision': 'parcel',
#              'gross_living_area_sqft': 1410,
#              'hc_mls_id': None,
#              'housecanary_value': 299803,
#              'is_distressed': None,
#              'is_in_non_disclosure_state': True,
#              'is_owner_occupied': True,
#              'last_list_date': '',
#              'last_list_price': None,
#              'leased_date': '',
#              'leased_price': None,
#              'listing_entity_id': None,
#              'pool': False,
#              'property_status': None,
#              'property_type': 'Single Family Detached',
#              'quality': 'CON3',
#              'raw_land_use_code': None,
#              'rental_avm': {'fsd': 0.0939664,
#                             'price_lwr': 1833,
#                             'price_mean': 2022,
#                             'price_per_sqft_lwr': 1.3,
#                             'price_per_sqft_mean': 1.4340425531914893,
#                             'price_per_sqft_upr': 1.5695035460992908,
#                             'price_upr': 2213,
#                             'valuation_suitability_score': 91,
#                             'valuation_suitability_score_desc': 'high'},
#              'sales_date': '',
#              'sales_price': None,
#              'site_area_sqft': 10454,
#              'state': 'AK',
#              'stories': None,
#              'street_address': '517 N Chugach St',
#              'subdivision_name': 'Riverside',
#              'tab_block_id': '021700012011002',
#              'tract_id': '02170001201',
#              'unit': None,
#              'unit_designator': None,
#              'year_built': 1982,
#              'zipcode': '99645',
#              'zipcode4': '6039'},
#  'version': '1'}

# %%
# Now lets try our actual intended call MSA Batch Gross Rental Yield

url = 'https://api.housecanary.com/v2/msa/hcri'

params = {'msa': '38060',
          'msa': '29820',
          'format': 'json'}

response = requests.get(url, params=params, auth=(test_key, test_secret))

print(response.url)
pprint.pprint(response.json())
# Out:
# https://api.housecanary.com/v2/msa/hcri?msa=29820&format=json
# {'message': 'Parameter not allowed in query string: format'}

# %%
# Now lets try our actual intended call MSA Batch Gross Rental Yield
url = 'https://api.housecanary.com/v2/msa/hcri'

# Assuming the API allows multiple 'msa' parameters
params = [('msa', '35620'), ('msa', '31080')]

response = requests.get(url, params=params, auth=(test_key, test_secret))

print(response.url)
pprint.pprint(response.json())
# Out:
# https://api.housecanary.com/v2/msa/hcri?msa=35620&msa=31080
# {'code': 403,
#  'message': 'This is an invalid MSA.  Test API keys will only work with MSA '
#             'IDs available from this endpoint: '
#             'https://api.housecanary.com/v2/msa/test_msas'}

# %% [markdown]
# **#1. Remove 'MSA' from the primary Name Column**

# %% [markdown]
# **#2. Remove intigers from the primary Name Column**

# %% [markdown]
# **#3. Clean up the Column Names**

# %% [markdown]
# **#4. Perform fuzzy matching to match Metropolitan Area to the official Census MSA Name**
