# %% [markdown]
# # Week 7-6 Charts - Python

# %% [markdown]
# author: Rodrigo Rodriguez
#
# date: 2024-17/24

# %% [markdown]
# ## 4.2 Exercises: Scatterplots, Bubble Charts, & Density Plots/Maps

# %% [markdown]
# **Instructions)**
#
# Generate the following from the practice datasets.
#
# 1 scatterplot, 1 bubble chart and 1 density plot chart using Python

# %% [markdown]
# **Answer)**

# %% [markdown]
# ### *Plots*

# %% [markdown]
# *Reading and opening the data*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# reading the data
crDF = pd.read_csv('C:/Users/ivan2/OneDrive/Documents/School/BU/DSC 640 Data Presentation - Visualization/Sample Datasets/ex4-2/crimerates-by-state-2005.csv')
crDF.head(5)
# Out:
#            state  murder  forcible_rape  robbery  aggravated_assault  \
# 0  United States     5.6           31.7    140.7               291.1
# 1        Alabama     8.2           34.3    141.4               247.8
# 2         Alaska     4.8           81.1     80.9               465.1
# 3        Arizona     7.5           33.8    144.4               327.4
# 4       Arkansas     6.7           42.9     91.1               386.8
#
#    burglary  larceny_theft  motor_vehicle_theft  population
# 0     726.7         2286.3                416.7   295753151
# 1     953.8         2650.0                288.3     4545049
# 2     622.5         2599.1                391.0      669488
# 3     948.4         2965.2                924.4     5974834
# 4    1084.6         2711.2                262.1     2776221

# %%
crDF.dtypes
# Out:
# state                   object
# murder                 float64
# forcible_rape          float64
# robbery                float64
# aggravated_assault     float64
# burglary               float64
# larceny_theft          float64
# motor_vehicle_theft    float64
# population               int64
# dtype: object

# %% [markdown]
#  Now I’ll create the Density Plot.

# %%
# filter out the 'United States' record
crDF_filtered = crDF[crDF['state'] != 'United States']

# set up the matplotlib figure
plt.figure(figsize=(8, 6))

# create the density plot with seaborn
sns.kdeplot(crDF_filtered['population'], fill=True, color="blue", alpha=0.5)

# plot labels
plt.title('Python - Density Plot: Density Plot of Population')
plt.xlabel('Population')
plt.ylabel('Density')

# plot
plt.show()

# %% [markdown]
#  Now I’ll create the scatterplot.

# %%
# set up the figure and create the plot
plt.figure(figsize=(10, 6))
plt.scatter(crDF_filtered['murder'], crDF_filtered['aggravated_assault'])

# plot labels
plt.title('Python - Scatter Plot: Plot of Murder vs Aggravated Assault')
plt.xlabel('Murder Rate (per 100,000)')
plt.ylabel('Aggravated Assault Rate (per 100,000)')

# plot
plt.show()

# %% [markdown]
# Now I'll create the bubble chart.

# %%
# first we need to filter the dataset to drop the D.C. outlier record
crDF_no_outlier = crDF_filtered[crDF_filtered['state'] != 'District of Columbia']

# set up the figure and create the plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(crDF_no_outlier['murder'], crDF_no_outlier['robbery'],
                      s=crDF_no_outlier['population'] / 40000,  # adjusting the wize of bubbles
                      alpha=0.6)

# plot labels
plt.title('Python - Bubble Chart: Chart of Murder vs Robbery with Population Size')
plt.xlabel('Murder Rate (per 100,000)')
plt.ylabel('Robbery Rate (per 100,000)')

# plot
plt.show()
