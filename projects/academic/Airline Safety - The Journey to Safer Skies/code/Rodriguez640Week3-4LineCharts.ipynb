# %% [markdown]
# # Week 3-4 Charts - Python

# %% [markdown]
# author: Rodrigo Rodriguez
#
# date: 2024-04-01

# %% [markdown]
# ## 2.2 Exercises: Line Charts and Step Charts

# %% [markdown]
# **Instructions)**
#
# Generate the following from the practice datasets.
#
# 1 line chart and 1 step chart using Python

# %% [markdown]
# **Answer)**

# %% [markdown]
# ### *Plots*

# %% [markdown]
# *Reading and opening the data*

# %%
import pandas as pd

# reading the data
wp_hs = pd.read_excel('C:/Users/ivan2/OneDrive/Documents/School/BU/DSC 640 Data Presentation - Visualization/Sample Datasets/ex2-2/world-population.xlsm')
wp_hs.head(5)
# Out:
#    Year  Population
# 0  1960  3028654024
# 1  1961  3068356747
# 2  1962  3121963107
# 3  1963  3187471383
# 4  1964  3253112403

# %%
import matplotlib.pyplot as plt

# %% [markdown]
#  Now I’ll create the line chart for world population.

# %%
# Group the data by Year and sum of Population
population_by_year = wp_hs.groupby('Year')['Population'].sum()

# Create a bar graph
plt.figure(figsize=(12, 8))
population_by_year.plot(kind='line', color='skyblue')
plt.title('Python - Line Chart: Sum of Population by Year')
plt.xlabel('Year')
plt.ylabel('Population in Billions')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %% [markdown]
#  Now I’ll create the Step chart for world population.

# %%
# Group the data by Year and sum of Population
population_by_year = wp_hs.groupby('Year')['Population'].sum()

# Create a step chart
plt.figure(figsize=(12, 8))
population_by_year.plot(kind='line', drawstyle='steps-post', color='skyblue')  # Using 'line' kind with 'steps-post' drawstyle for step chart
plt.title('Python - Step Chart: Sum of Population by Year')
plt.xlabel('Year')
plt.ylabel('Population in Billions')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()
